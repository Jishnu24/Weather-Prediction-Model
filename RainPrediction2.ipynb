# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
import scipy.stats as stats
from sklearn.model_selection import train_test_split
from collections import Counter
from imblearn.over_sampling import SMOTE
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
import joblib

# %%
df = pd.read_csv("weatherAUS.csv")
pd.set_option("display.max_columns", None)
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am WindDir3pm  \
# 0            NaN           W           44.0          W        WNW
# 1            NaN         WNW           44.0        NNW        WSW
# 2            NaN         WSW           46.0          W        WSW
# 3            NaN          NE           24.0         SE          E
# 4            NaN           W           41.0        ENE         NW
# ...          ...         ...            ...        ...        ...
# 145455       NaN           E           31.0         SE        ENE
# 145456       NaN         NNW           22.0         SE          N
# 145457       NaN           N           37.0         SE        WNW
# 145458       NaN          SE           28.0        SSE          N
# 145459       NaN         NaN            NaN        ESE        ESE
#
#         WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 0               20.0          24.0         71.0         22.0       1007.7
# 1                4.0          22.0         44.0         25.0       1010.6
# 2               19.0          26.0         38.0         30.0       1007.6
# 3               11.0           9.0         45.0         16.0       1017.6
# 4                7.0          20.0         82.0         33.0       1010.8
# ...              ...           ...          ...          ...          ...
# 145455          13.0          11.0         51.0         24.0       1024.6
# 145456          13.0           9.0         56.0         21.0       1023.5
# 145457           9.0           9.0         53.0         24.0       1021.0
# 145458          13.0           7.0         51.0         24.0       1019.4
# 145459          17.0          17.0         62.0         36.0       1020.2
#
#         Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm RainToday  \
# 0            1007.1       8.0       NaN     16.9     21.8        No
# 1            1007.8       NaN       NaN     17.2     24.3        No
# 2            1008.7       NaN       2.0     21.0     23.2        No
# 3            1012.8       NaN       NaN     18.1     26.5        No
# 4            1006.0       7.0       8.0     17.8     29.7        No
# ...             ...       ...       ...      ...      ...       ...
# 145455       1020.3       NaN       NaN     10.1     22.4        No
# 145456       1019.1       NaN       NaN     10.9     24.5        No
# 145457       1016.8       NaN       NaN     12.5     26.1        No
# 145458       1016.5       3.0       2.0     15.1     26.0        No
# 145459       1017.9       8.0       8.0     15.0     20.9        No
#
#        RainTomorrow
# 0                No
# 1                No
# 2                No
# 3                No
# 4                No
# ...             ...
# 145455           No
# 145456           No
# 145457           No
# 145458           No
# 145459          NaN
#
# [145460 rows x 23 columns]

# %%
numerical_feature = [feature for feature in df.columns if df[feature].dtypes != 'O']
discrete_feature=[feature for feature in numerical_feature if len(df[feature].unique())<25]
continuous_feature = [feature for feature in numerical_feature if feature not in discrete_feature]
categorical_feature = [feature for feature in df.columns if feature not in numerical_feature]
print("Numerical Features Count {}".format(len(numerical_feature)))
print("Discrete feature Count {}".format(len(discrete_feature)))
print("Continuous feature Count {}".format(len(continuous_feature)))
print("Categorical feature Count {}".format(len(categorical_feature)))
# Out:
# Numerical Features Count 16
# Discrete feature Count 2
# Continuous feature Count 14
# Categorical feature Count 7

# %%
# Handle Missing Values
df.isnull().sum()*100/len(df)
# Out:
# Date              0.000000
# Location          0.000000
# MinTemp           1.020899
# MaxTemp           0.866905
# Rainfall          2.241853
# Evaporation      43.166506
# Sunshine         48.009762
# WindGustDir       7.098859
# WindGustSpeed     7.055548
# WindDir9am        7.263853
# WindDir3pm        2.906641
# WindSpeed9am      1.214767
# WindSpeed3pm      2.105046
# Humidity9am       1.824557
# Humidity3pm       3.098446
# Pressure9am      10.356799
# Pressure3pm      10.331363
# Cloud9am         38.421559
# Cloud3pm         40.807095
# Temp9am           1.214767
# Temp3pm           2.481094
# RainToday         2.241853
# RainTomorrow      2.245978
# dtype: float64

# %%
print(numerical_feature)
# Out:
# ['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm']

# %%
def randomsampleimputation(df, variable):
    df[variable]=df[variable]
    random_sample=df[variable].dropna().sample(df[variable].isnull().sum(),random_state=0)
    random_sample.index=df[df[variable].isnull()].index
    df.loc[df[variable].isnull(),variable]=random_sample

# %%
randomsampleimputation(df, "Cloud9am")
randomsampleimputation(df, "Cloud3pm")
randomsampleimputation(df, "Evaporation")
randomsampleimputation(df, "Sunshine")

# %%
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          2.4
# 1       2008-12-02   Albury      7.4     25.1       0.0          3.6
# 2       2008-12-03   Albury     12.9     25.7       0.0          2.6
# 3       2008-12-04   Albury      9.2     28.0       0.0         18.4
# 4       2008-12-05   Albury     17.5     32.3       1.0          5.4
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          1.4
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          7.6
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          6.8
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          2.6
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          1.4
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am WindDir3pm  \
# 0            8.3           W           44.0          W        WNW
# 1           10.0         WNW           44.0        NNW        WSW
# 2            4.4         WSW           46.0          W        WSW
# 3            8.9          NE           24.0         SE          E
# 4            3.0           W           41.0        ENE         NW
# ...          ...         ...            ...        ...        ...
# 145455       7.8           E           31.0         SE        ENE
# 145456      13.5         NNW           22.0         SE          N
# 145457      11.0           N           37.0         SE        WNW
# 145458      13.2          SE           28.0        SSE          N
# 145459       0.7         NaN            NaN        ESE        ESE
#
#         WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 0               20.0          24.0         71.0         22.0       1007.7
# 1                4.0          22.0         44.0         25.0       1010.6
# 2               19.0          26.0         38.0         30.0       1007.6
# 3               11.0           9.0         45.0         16.0       1017.6
# 4                7.0          20.0         82.0         33.0       1010.8
# ...              ...           ...          ...          ...          ...
# 145455          13.0          11.0         51.0         24.0       1024.6
# 145456          13.0           9.0         56.0         21.0       1023.5
# 145457           9.0           9.0         53.0         24.0       1021.0
# 145458          13.0           7.0         51.0         24.0       1019.4
# 145459          17.0          17.0         62.0         36.0       1020.2
#
#         Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm RainToday  \
# 0            1007.1       8.0       0.0     16.9     21.8        No
# 1            1007.8       7.0       1.0     17.2     24.3        No
# 2            1008.7       8.0       2.0     21.0     23.2        No
# 3            1012.8       0.0       5.0     18.1     26.5        No
# 4            1006.0       7.0       8.0     17.8     29.7        No
# ...             ...       ...       ...      ...      ...       ...
# 145455       1020.3       1.0       1.0     10.1     22.4        No
# 145456       1019.1       8.0       5.0     10.9     24.5        No
# 145457       1016.8       8.0       1.0     12.5     26.1        No
# 145458       1016.5       3.0       2.0     15.1     26.0        No
# 145459       1017.9       8.0       8.0     15.0     20.9        No
#
#        RainTomorrow
# 0                No
# 1                No
# 2                No
# 3                No
# 4                No
# ...             ...
# 145455           No
# 145456           No
# 145457           No
# 145458           No
# 145459          NaN
#
# [145460 rows x 23 columns]

# %%
corrmat = df.corr(method = "spearman")
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(corrmat,annot=True)
# Out:
# C:\Users\91707\AppData\Local\Temp\ipykernel_6340\2689263927.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrmat = df.corr(method = "spearman")

# %%
for feature in continuous_feature:
    data=df.copy()
    sns.distplot(df[feature])
    plt.xlabel(feature)
    plt.ylabel("Count")
    plt.title(feature)
    plt.figure(figsize=(15,15))
    plt.show()
# Out:
# C:\Users\91707\AppData\Local\Temp\ipykernel_6340\2600242752.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[feature])
# C:\Users\91707\AppData\Local\Temp\ipykernel_6340\2600242752.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[feature])
# C:\Users\91707\AppData\Local\Temp\ipykernel_6340\2600242752.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[feature])
# C:\Users\91707\AppData\Local\Temp\ipykernel_6340\2600242752.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[feature])
# C:\Users\91707\AppData\Local\Temp\ipykernel_6340\2600242752.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[feature])
# C:\Users\91707\AppData\Local\Temp\ipykernel_6340\2600242752.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[feature])
# C:\Users\91707\AppData\Local\Temp\ipykernel_6340\2600242752.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[feature])
# C:\Users\91707\AppData\Local\Temp\ipykernel_6340\2600242752.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[feature])
# C:\Users\91707\AppData\Local\Temp\ipykernel_6340\2600242752.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[feature])
# C:\Users\91707\AppData\Local\Temp\ipykernel_6340\2600242752.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[feature])
# C:\Users\91707\AppData\Local\Temp\ipykernel_6340\2600242752.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[feature])
# C:\Users\91707\AppData\Local\Temp\ipykernel_6340\2600242752.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[feature])
# C:\Users\91707\AppData\Local\Temp\ipykernel_6340\2600242752.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[feature])
# C:\Users\91707\AppData\Local\Temp\ipykernel_6340\2600242752.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[feature])

# %%
#A for loop is used to plot a boxplot for all the continuous features to see the outliers
for feature in continuous_feature:
    data=df.copy()
    sns.boxplot(data[feature])
    plt.title(feature)
    plt.figure(figsize=(15,15))

# %%
for feature in continuous_feature:
    if(df[feature].isnull().sum()*100/len(df))>0:
        df[feature] = df[feature].fillna(df[feature].median())

# %%
df.isnull().sum()*100/len(df)
# Out:
# Date             0.000000
# Location         0.000000
# MinTemp          0.000000
# MaxTemp          0.000000
# Rainfall         0.000000
# Evaporation      0.000000
# Sunshine         0.000000
# WindGustDir      7.098859
# WindGustSpeed    0.000000
# WindDir9am       7.263853
# WindDir3pm       2.906641
# WindSpeed9am     0.000000
# WindSpeed3pm     0.000000
# Humidity9am      0.000000
# Humidity3pm      0.000000
# Pressure9am      0.000000
# Pressure3pm      0.000000
# Cloud9am         0.000000
# Cloud3pm         0.000000
# Temp9am          0.000000
# Temp3pm          0.000000
# RainToday        2.241853
# RainTomorrow     2.245978
# dtype: float64

# %%
discrete_feature
# Out:
# ['Cloud9am', 'Cloud3pm']

# %%
def mode_nan(df,variable):
    mode=df[variable].value_counts().index[0]
    df[variable].fillna(mode,inplace=True)
mode_nan(df,"Cloud9am")
mode_nan(df,"Cloud3pm")

# %%
df["RainToday"] = pd.get_dummies(df["RainToday"], drop_first = True)
df["RainTomorrow"] = pd.get_dummies(df["RainTomorrow"], drop_first = True)
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          2.4
# 1       2008-12-02   Albury      7.4     25.1       0.0          3.6
# 2       2008-12-03   Albury     12.9     25.7       0.0          2.6
# 3       2008-12-04   Albury      9.2     28.0       0.0         18.4
# 4       2008-12-05   Albury     17.5     32.3       1.0          5.4
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          1.4
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          7.6
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          6.8
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          2.6
# 145459  2017-06-25    Uluru     14.9     22.6       0.0          1.4
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am WindDir3pm  \
# 0            8.3           W           44.0          W        WNW
# 1           10.0         WNW           44.0        NNW        WSW
# 2            4.4         WSW           46.0          W        WSW
# 3            8.9          NE           24.0         SE          E
# 4            3.0           W           41.0        ENE         NW
# ...          ...         ...            ...        ...        ...
# 145455       7.8           E           31.0         SE        ENE
# 145456      13.5         NNW           22.0         SE          N
# 145457      11.0           N           37.0         SE        WNW
# 145458      13.2          SE           28.0        SSE          N
# 145459       0.7         NaN           39.0        ESE        ESE
#
#         WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 0               20.0          24.0         71.0         22.0       1007.7
# 1                4.0          22.0         44.0         25.0       1010.6
# 2               19.0          26.0         38.0         30.0       1007.6
# 3               11.0           9.0         45.0         16.0       1017.6
# 4                7.0          20.0         82.0         33.0       1010.8
# ...              ...           ...          ...          ...          ...
# 145455          13.0          11.0         51.0         24.0       1024.6
# 145456          13.0           9.0         56.0         21.0       1023.5
# 145457           9.0           9.0         53.0         24.0       1021.0
# 145458          13.0           7.0         51.0         24.0       1019.4
# 145459          17.0          17.0         62.0         36.0       1020.2
#
#         Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0            1007.1       8.0       0.0     16.9     21.8          0
# 1            1007.8       7.0       1.0     17.2     24.3          0
# 2            1008.7       8.0       2.0     21.0     23.2          0
# 3            1012.8       0.0       5.0     18.1     26.5          0
# 4            1006.0       7.0       8.0     17.8     29.7          0
# ...             ...       ...       ...      ...      ...        ...
# 145455       1020.3       1.0       1.0     10.1     22.4          0
# 145456       1019.1       8.0       5.0     10.9     24.5          0
# 145457       1016.8       8.0       1.0     12.5     26.1          0
# 145458       1016.5       3.0       2.0     15.1     26.0          0
# 145459       1017.9       8.0       8.0     15.0     20.9          0
#
#         RainTomorrow
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 145455             0
# 145456             0
# 145457             0
# 145458             0
# 145459             0
#
# [145460 rows x 23 columns]

# %%
for feature in categorical_feature:
    print(feature, (df.groupby([feature])["RainTomorrow"].mean().sort_values(ascending = False)).index)
# Out:
# Date Index(['2007-11-01', '2007-12-15', '2008-02-03', '2008-01-31', '2008-01-30',
#        '2008-01-19', '2008-01-18', '2008-01-16', '2008-01-12', '2007-11-30',
#        ...
#        '2008-05-08', '2008-05-09', '2008-01-03', '2008-01-02', '2008-05-10',
#        '2008-05-11', '2008-05-12', '2008-05-13', '2008-05-14', '2007-12-25'],
#       dtype='object', name='Date', length=3436)
# Location Index(['Portland', 'Walpole', 'Cairns', 'Dartmoor', 'NorfolkIsland',
#        'MountGambier', 'Albany', 'Witchcliffe', 'CoffsHarbour', 'MountGinini',
#        'NorahHead', 'Darwin', 'Sydney', 'SydneyAirport', 'Ballarat',
#        'GoldCoast', 'Watsonia', 'Newcastle', 'Hobart', 'Wollongong',
#        'Williamtown', 'Launceston', 'Brisbane', 'MelbourneAirport', 'Adelaide',
#        'Sale', 'Albury', 'Perth', 'Melbourne', 'Nuriootpa', 'Penrith',
#        'BadgerysCreek', 'PerthAirport', 'Tuggeranong', 'Richmond', 'Bendigo',
#        'Canberra', 'WaggaWagga', 'Townsville', 'Katherine', 'PearceRAAF',
#        'SalmonGums', 'Nhil', 'Moree', 'Cobar', 'Mildura', 'AliceSprings',
#        'Uluru', 'Woomera'],
#       dtype='object', name='Location')
# WindGustDir Index(['NNW', 'NW', 'WNW', 'N', 'W', 'WSW', 'NNE', 'S', 'SSW', 'SW', 'SSE',
#        'NE', 'SE', 'ESE', 'ENE', 'E'],
#       dtype='object', name='WindGustDir')
# WindDir9am Index(['NNW', 'N', 'NW', 'NNE', 'WNW', 'W', 'WSW', 'SW', 'SSW', 'NE', 'S',
#        'SSE', 'ENE', 'SE', 'ESE', 'E'],
#       dtype='object', name='WindDir9am')
# WindDir3pm Index(['NW', 'NNW', 'N', 'WNW', 'W', 'NNE', 'WSW', 'SSW', 'S', 'SW', 'SE',
#        'NE', 'SSE', 'ENE', 'E', 'ESE'],
#       dtype='object', name='WindDir3pm')
# RainToday UInt64Index([1, 0], dtype='uint64', name='RainToday')
# RainTomorrow UInt64Index([1, 0], dtype='uint64', name='RainTomorrow')

# %%
windgustdir = {'NNW':0, 'NW':1, 'WNW':2, 'N':3, 'W':4, 'WSW':5, 'NNE':6, 'S':7, 'SSW':8, 'SW':9, 'SSE':10,
       'NE':11, 'SE':12, 'ESE':13, 'ENE':14, 'E':15}
winddir9am = {'NNW':0, 'N':1, 'NW':2, 'NNE':3, 'WNW':4, 'W':5, 'WSW':6, 'SW':7, 'SSW':8, 'NE':9, 'S':10,
       'SSE':11, 'ENE':12, 'SE':13, 'ESE':14, 'E':15}
winddir3pm = {'NW':0, 'NNW':1, 'N':2, 'WNW':3, 'W':4, 'NNE':5, 'WSW':6, 'SSW':7, 'S':8, 'SW':9, 'SE':10,
       'NE':11, 'SSE':12, 'ENE':13, 'E':14, 'ESE':15}
df["WindGustDir"] = df["WindGustDir"].map(windgustdir)
df["WindDir9am"] = df["WindDir9am"].map(winddir9am)
df["WindDir3pm"] = df["WindDir3pm"].map(winddir3pm)

# %%
df["WindGustDir"] = df["WindGustDir"].fillna(df["WindGustDir"].value_counts().index[0])
df["WindDir9am"] = df["WindDir9am"].fillna(df["WindDir9am"].value_counts().index[0])
df["WindDir3pm"] = df["WindDir3pm"].fillna(df["WindDir3pm"].value_counts().index[0])

# %%
df.isnull().sum()*100/len(df)
# Out:
# Date             0.0
# Location         0.0
# MinTemp          0.0
# MaxTemp          0.0
# Rainfall         0.0
# Evaporation      0.0
# Sunshine         0.0
# WindGustDir      0.0
# WindGustSpeed    0.0
# WindDir9am       0.0
# WindDir3pm       0.0
# WindSpeed9am     0.0
# WindSpeed3pm     0.0
# Humidity9am      0.0
# Humidity3pm      0.0
# Pressure9am      0.0
# Pressure3pm      0.0
# Cloud9am         0.0
# Cloud3pm         0.0
# Temp9am          0.0
# Temp3pm          0.0
# RainToday        0.0
# RainTomorrow     0.0
# dtype: float64

# %%
df1 = df.groupby(["Location"])["RainTomorrow"].value_counts().sort_values().unstack()

# %%
df1
# Out:
# RainTomorrow         0     1
# Location
# Adelaide          2505   688
# Albany            2138   902
# Albury            2422   618
# AliceSprings      2796   244
# BadgerysCreek     2426   583
# Ballarat          2259   781
# Bendigo           2478   562
# Brisbane          2484   709
# Cairns            2090   950
# Canberra          2807   629
# Cobar             2623   386
# CoffsHarbour      2140   869
# Dartmoor          2087   922
# Darwin            2341   852
# GoldCoast         2265   775
# Hobart            2432   761
# Katherine         1313   265
# Launceston        2341   699
# Melbourne         2557   636
# MelbourneAirport  2356   653
# Mildura           2682   327
# Moree             2615   394
# MountGambier      2120   920
# MountGinini       2221   819
# Newcastle         2308   731
# Nhil              1336   242
# NorahHead         2196   808
# NorfolkIsland     2090   919
# Nuriootpa         2417   592
# PearceRAAF        2504   505
# Penrith           2444   595
# Perth             2548   645
# PerthAirport      2442   567
# Portland          1914  1095
# Richmond          2449   560
# Sale              2366   643
# SalmonGums        2529   472
# Sydney            2479   865
# SydneyAirport     2235   774
# Townsville        2521   519
# Tuggeranong       2471   568
# Uluru             1462   116
# WaggaWagga        2473   536
# Walpole           2057   949
# Watsonia          2271   738
# Williamtown       2309   700
# Witchcliffe       2130   879
# Wollongong        2327   713
# Woomera           2807   202

# %%
df1[1].sort_values(ascending = False)
# Out:
# Location
# Portland            1095
# Cairns               950
# Walpole              949
# Dartmoor             922
# MountGambier         920
# NorfolkIsland        919
# Albany               902
# Witchcliffe          879
# CoffsHarbour         869
# Sydney               865
# Darwin               852
# MountGinini          819
# NorahHead            808
# Ballarat             781
# GoldCoast            775
# SydneyAirport        774
# Hobart               761
# Watsonia             738
# Newcastle            731
# Wollongong           713
# Brisbane             709
# Williamtown          700
# Launceston           699
# Adelaide             688
# MelbourneAirport     653
# Perth                645
# Sale                 643
# Melbourne            636
# Canberra             629
# Albury               618
# Penrith              595
# Nuriootpa            592
# BadgerysCreek        583
# Tuggeranong          568
# PerthAirport         567
# Bendigo              562
# Richmond             560
# WaggaWagga           536
# Townsville           519
# PearceRAAF           505
# SalmonGums           472
# Moree                394
# Cobar                386
# Mildura              327
# Katherine            265
# AliceSprings         244
# Nhil                 242
# Woomera              202
# Uluru                116
# Name: 1, dtype: int64

# %%
df1[1].sort_values(ascending = False).index
# Out:
# Index(['Portland', 'Cairns', 'Walpole', 'Dartmoor', 'MountGambier',
#        'NorfolkIsland', 'Albany', 'Witchcliffe', 'CoffsHarbour', 'Sydney',
#        'Darwin', 'MountGinini', 'NorahHead', 'Ballarat', 'GoldCoast',
#        'SydneyAirport', 'Hobart', 'Watsonia', 'Newcastle', 'Wollongong',
#        'Brisbane', 'Williamtown', 'Launceston', 'Adelaide', 'MelbourneAirport',
#        'Perth', 'Sale', 'Melbourne', 'Canberra', 'Albury', 'Penrith',
#        'Nuriootpa', 'BadgerysCreek', 'Tuggeranong', 'PerthAirport', 'Bendigo',
#        'Richmond', 'WaggaWagga', 'Townsville', 'PearceRAAF', 'SalmonGums',
#        'Moree', 'Cobar', 'Mildura', 'Katherine', 'AliceSprings', 'Nhil',
#        'Woomera', 'Uluru'],
#       dtype='object', name='Location')

# %%
len(df1[1].sort_values(ascending = False).index)
# Out:
# 49

# %%
location = {'Portland':1, 'Cairns':2, 'Walpole':3, 'Dartmoor':4, 'MountGambier':5,
       'NorfolkIsland':6, 'Albany':7, 'Witchcliffe':8, 'CoffsHarbour':9, 'Sydney':10,
       'Darwin':11, 'MountGinini':12, 'NorahHead':13, 'Ballarat':14, 'GoldCoast':15,
       'SydneyAirport':16, 'Hobart':17, 'Watsonia':18, 'Newcastle':19, 'Wollongong':20,
       'Brisbane':21, 'Williamtown':22, 'Launceston':23, 'Adelaide':24, 'MelbourneAirport':25,
       'Perth':26, 'Sale':27, 'Melbourne':28, 'Canberra':29, 'Albury':30, 'Penrith':31,
       'Nuriootpa':32, 'BadgerysCreek':33, 'Tuggeranong':34, 'PerthAirport':35, 'Bendigo':36,
       'Richmond':37, 'WaggaWagga':38, 'Townsville':39, 'PearceRAAF':40, 'SalmonGums':41,
       'Moree':42, 'Cobar':43, 'Mildura':44, 'Katherine':45, 'AliceSprings':46, 'Nhil':47,
       'Woomera':48, 'Uluru':49}
df["Location"] = df["Location"].map(location)

# %%
df["Date"] = pd.to_datetime(df["Date"], format = "%Y-%m-%dT", errors = "coerce")

# %%
df["Date_month"] = df["Date"].dt.month
df["Date_day"] = df["Date"].dt.day

# %%
df
# Out:
#              Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0      2008-12-01        30     13.4     22.9       0.6          2.4
# 1      2008-12-02        30      7.4     25.1       0.0          3.6
# 2      2008-12-03        30     12.9     25.7       0.0          2.6
# 3      2008-12-04        30      9.2     28.0       0.0         18.4
# 4      2008-12-05        30     17.5     32.3       1.0          5.4
# ...           ...       ...      ...      ...       ...          ...
# 145455 2017-06-21        49      2.8     23.4       0.0          1.4
# 145456 2017-06-22        49      3.6     25.3       0.0          7.6
# 145457 2017-06-23        49      5.4     26.9       0.0          6.8
# 145458 2017-06-24        49      7.8     27.0       0.0          2.6
# 145459 2017-06-25        49     14.9     22.6       0.0          1.4
#
#         Sunshine  WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  \
# 0            8.3          4.0           44.0         5.0         3.0
# 1           10.0          2.0           44.0         0.0         6.0
# 2            4.4          5.0           46.0         5.0         6.0
# 3            8.9         11.0           24.0        13.0        14.0
# 4            3.0          4.0           41.0        12.0         0.0
# ...          ...          ...            ...         ...         ...
# 145455       7.8         15.0           31.0        13.0        13.0
# 145456      13.5          0.0           22.0        13.0         2.0
# 145457      11.0          3.0           37.0        13.0         3.0
# 145458      13.2         12.0           28.0        11.0         2.0
# 145459       0.7          4.0           39.0        14.0        15.0
#
#         WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 0               20.0          24.0         71.0         22.0       1007.7
# 1                4.0          22.0         44.0         25.0       1010.6
# 2               19.0          26.0         38.0         30.0       1007.6
# 3               11.0           9.0         45.0         16.0       1017.6
# 4                7.0          20.0         82.0         33.0       1010.8
# ...              ...           ...          ...          ...          ...
# 145455          13.0          11.0         51.0         24.0       1024.6
# 145456          13.0           9.0         56.0         21.0       1023.5
# 145457           9.0           9.0         53.0         24.0       1021.0
# 145458          13.0           7.0         51.0         24.0       1019.4
# 145459          17.0          17.0         62.0         36.0       1020.2
#
#         Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0            1007.1       8.0       0.0     16.9     21.8          0
# 1            1007.8       7.0       1.0     17.2     24.3          0
# 2            1008.7       8.0       2.0     21.0     23.2          0
# 3            1012.8       0.0       5.0     18.1     26.5          0
# 4            1006.0       7.0       8.0     17.8     29.7          0
# ...             ...       ...       ...      ...      ...        ...
# 145455       1020.3       1.0       1.0     10.1     22.4          0
# 145456       1019.1       8.0       5.0     10.9     24.5          0
# 145457       1016.8       8.0       1.0     12.5     26.1          0
# 145458       1016.5       3.0       2.0     15.1     26.0          0
# 145459       1017.9       8.0       8.0     15.0     20.9          0
#
#         RainTomorrow  Date_month  Date_day
# 0                  0          12         1
# 1                  0          12         2
# 2                  0          12         3
# 3                  0          12         4
# 4                  0          12         5
# ...              ...         ...       ...
# 145455             0           6        21
# 145456             0           6        22
# 145457             0           6        23
# 145458             0           6        24
# 145459             0           6        25
#
# [145460 rows x 25 columns]

# %%
corrmat = df.corr()
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(corrmat,annot=True)
# Out:
# C:\Users\91707\AppData\Local\Temp\ipykernel_6340\3423568062.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrmat = df.corr()

# %%
df
# Out:
#              Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0      2008-12-01        30     13.4     22.9       0.6          2.4
# 1      2008-12-02        30      7.4     25.1       0.0          3.6
# 2      2008-12-03        30     12.9     25.7       0.0          2.6
# 3      2008-12-04        30      9.2     28.0       0.0         18.4
# 4      2008-12-05        30     17.5     32.3       1.0          5.4
# ...           ...       ...      ...      ...       ...          ...
# 145455 2017-06-21        49      2.8     23.4       0.0          1.4
# 145456 2017-06-22        49      3.6     25.3       0.0          7.6
# 145457 2017-06-23        49      5.4     26.9       0.0          6.8
# 145458 2017-06-24        49      7.8     27.0       0.0          2.6
# 145459 2017-06-25        49     14.9     22.6       0.0          1.4
#
#         Sunshine  WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  \
# 0            8.3          4.0           44.0         5.0         3.0
# 1           10.0          2.0           44.0         0.0         6.0
# 2            4.4          5.0           46.0         5.0         6.0
# 3            8.9         11.0           24.0        13.0        14.0
# 4            3.0          4.0           41.0        12.0         0.0
# ...          ...          ...            ...         ...         ...
# 145455       7.8         15.0           31.0        13.0        13.0
# 145456      13.5          0.0           22.0        13.0         2.0
# 145457      11.0          3.0           37.0        13.0         3.0
# 145458      13.2         12.0           28.0        11.0         2.0
# 145459       0.7          4.0           39.0        14.0        15.0
#
#         WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 0               20.0          24.0         71.0         22.0       1007.7
# 1                4.0          22.0         44.0         25.0       1010.6
# 2               19.0          26.0         38.0         30.0       1007.6
# 3               11.0           9.0         45.0         16.0       1017.6
# 4                7.0          20.0         82.0         33.0       1010.8
# ...              ...           ...          ...          ...          ...
# 145455          13.0          11.0         51.0         24.0       1024.6
# 145456          13.0           9.0         56.0         21.0       1023.5
# 145457           9.0           9.0         53.0         24.0       1021.0
# 145458          13.0           7.0         51.0         24.0       1019.4
# 145459          17.0          17.0         62.0         36.0       1020.2
#
#         Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0            1007.1       8.0       0.0     16.9     21.8          0
# 1            1007.8       7.0       1.0     17.2     24.3          0
# 2            1008.7       8.0       2.0     21.0     23.2          0
# 3            1012.8       0.0       5.0     18.1     26.5          0
# 4            1006.0       7.0       8.0     17.8     29.7          0
# ...             ...       ...       ...      ...      ...        ...
# 145455       1020.3       1.0       1.0     10.1     22.4          0
# 145456       1019.1       8.0       5.0     10.9     24.5          0
# 145457       1016.8       8.0       1.0     12.5     26.1          0
# 145458       1016.5       3.0       2.0     15.1     26.0          0
# 145459       1017.9       8.0       8.0     15.0     20.9          0
#
#         RainTomorrow  Date_month  Date_day
# 0                  0          12         1
# 1                  0          12         2
# 2                  0          12         3
# 3                  0          12         4
# 4                  0          12         5
# ...              ...         ...       ...
# 145455             0           6        21
# 145456             0           6        22
# 145457             0           6        23
# 145458             0           6        24
# 145459             0           6        25
#
# [145460 rows x 25 columns]

# %%
for feature in continuous_feature:
    data=df.copy()
    sns.boxplot(data[feature])
    plt.title(feature)
    plt.figure(figsize=(15,15))

# %%
for feature in continuous_feature:
    print(feature)
# Out:
# MinTemp
# MaxTemp
# Rainfall
# Evaporation
# Sunshine
# WindGustSpeed
# WindSpeed9am
# WindSpeed3pm
# Humidity9am
# Humidity3pm
# Pressure9am
# Pressure3pm
# Temp9am
# Temp3pm

# %%
IQR=df.MinTemp.quantile(0.75)-df.MinTemp.quantile(0.25)
lower_bridge=df.MinTemp.quantile(0.25)-(IQR*1.5)
upper_bridge=df.MinTemp.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# -5.950000000000002 30.450000000000003

# %%
df.loc[df['MinTemp']>=30.45,'MinTemp']=30.45
df.loc[df['MinTemp']<=-5.95,'MinTemp']=-5.95

# %%
IQR=df.MaxTemp.quantile(0.75)-df.MaxTemp.quantile(0.25)
lower_bridge=df.MaxTemp.quantile(0.25)-(IQR*1.5)
upper_bridge=df.MaxTemp.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# 2.700000000000001 43.5

# %%
df.loc[df['MaxTemp']>=43.5,'MaxTemp']=43.5
df.loc[df['MaxTemp']<=2.7,'MaxTemp']=2.7

# %%
IQR=df.Rainfall.quantile(0.75)-df.Rainfall.quantile(0.25)
lower_bridge=df.Rainfall.quantile(0.25)-(IQR*1.5)
upper_bridge=df.Rainfall.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# -0.8999999999999999 1.5

# %%
df.loc[df['Rainfall']>=1.5,'Rainfall']=1.5
df.loc[df['Rainfall']<=-0.89,'Rainfall']=-0.89

# %%
IQR=df.Evaporation.quantile(0.75)-df.Evaporation.quantile(0.25)
lower_bridge=df.Evaporation.quantile(0.25)-(IQR*1.5)
upper_bridge=df.Evaporation.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# -4.600000000000001 14.600000000000001

# %%
df.loc[df['Evaporation']>=14.6,'Evaporation']=14.6
df.loc[df['Evaporation']<=-4.6,'Evaporation']=-4.6

# %%
IQR=df.WindGustSpeed.quantile(0.75)-df.WindGustSpeed.quantile(0.25)
lower_bridge=df.WindGustSpeed.quantile(0.25)-(IQR*1.5)
upper_bridge=df.WindGustSpeed.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# 8.5 68.5

# %%
df.loc[df['WindGustSpeed']>=68.5,'WindGustSpeed']=68.5
df.loc[df['WindGustSpeed']<=8.5,'WindGustSpeed']=8.5

# %%
IQR=df.WindSpeed9am.quantile(0.75)-df.WindSpeed9am.quantile(0.25)
lower_bridge=df.WindSpeed9am.quantile(0.25)-(IQR*1.5)
upper_bridge=df.WindSpeed9am.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# -11.0 37.0

# %%
df.loc[df['WindSpeed9am']>=37,'WindSpeed9am']=37
df.loc[df['WindSpeed9am']<=-11,'WindSpeed9am']=-11

# %%
IQR=df.WindSpeed3pm.quantile(0.75)-df.WindSpeed3pm.quantile(0.25)
lower_bridge=df.WindSpeed3pm.quantile(0.25)-(IQR*1.5)
upper_bridge=df.WindSpeed3pm.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# -3.5 40.5

# %%
df.loc[df['WindSpeed3pm']>40.5,'WindSpeed3pm']=40.5
df.loc[df['WindSpeed3pm']<=-3.5,'WindSpeed3pm']=-3.5

# %%
IQR=df.Humidity9am.quantile(0.75)-df.Humidity9am.quantile(0.25)
lower_bridge=df.Humidity9am.quantile(0.25)-(IQR*1.5)
upper_bridge=df.Humidity9am.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# 18.0 122.0

# %%
df.loc[df['Humidity9am']>=122,'Humidity9am']=122
df.loc[df['Humidity9am']<=18,'Humidity9am']=18

# %%
IQR=df.Pressure9am.quantile(0.75)-df.Pressure9am.quantile(0.25)
lower_bridge=df.Pressure9am.quantile(0.25)-(IQR*1.5)
upper_bridge=df.Pressure9am.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# 1001.0500000000001 1034.25

# %%
df.loc[df['Pressure9am']>=1034.25,'Pressure9am']=1034.25
df.loc[df['Pressure9am']<=1001.05,'Pressure9am']=1001.05

# %%
IQR=df.Pressure3pm.quantile(0.75)-df.Pressure3pm.quantile(0.25)
lower_bridge=df.Pressure3pm.quantile(0.25)-(IQR*1.5)
upper_bridge=df.Pressure3pm.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# 998.6500000000001 1031.85

# %%
df.loc[df['Pressure3pm']>=1031.85,'Pressure3pm']=1031.85
df.loc[df['Pressure3pm']<=998.65,'Pressure3pm']=998.65

# %%
IQR=df.Temp9am.quantile(0.75)-df.Temp9am.quantile(0.25)
lower_bridge=df.Temp9am.quantile(0.25)-(IQR*1.5)
upper_bridge=df.Temp9am.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# -1.4999999999999982 35.3

# %%
df.loc[df['Temp9am']>=35.3,'Temp9am']=35.3
df.loc[df['Temp9am']<=-1.49,'Temp9am']=-1.49

# %%
IQR=df.Temp3pm.quantile(0.75)-df.Temp3pm.quantile(0.25)
lower_bridge=df.Temp3pm.quantile(0.25)-(IQR*1.5)
upper_bridge=df.Temp3pm.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# 2.4499999999999993 40.45

# %%
df.loc[df['Temp3pm']>=40.45,'Temp3pm']=40.45
df.loc[df['Temp3pm']<=2.45,'Temp3pm']=2.45

# %%
for feature in continuous_feature:
    data=df.copy()
    sns.boxplot(data[feature])
    plt.title(feature)
    plt.figure(figsize=(15,15))

# %%
def qq_plots(df, variable):
    plt.figure(figsize=(15,6))
    plt.subplot(1, 2, 1)
    df[variable].hist()
    plt.subplot(1, 2, 2)
    stats.probplot(df[variable], dist="norm", plot=plt)
    plt.show()

# %%
for feature in continuous_feature:
    print(feature)
    plt.figure(figsize=(15,6))
    plt.subplot(1, 2, 1)
    df[feature].hist()
    plt.subplot(1, 2, 2)
    stats.probplot(df[feature], dist="norm", plot=plt)
    plt.show()
# Out:
# MinTemp
# MaxTemp
# Rainfall
# Evaporation
# Sunshine
# WindGustSpeed
# WindSpeed9am
# WindSpeed3pm
# Humidity9am
# Humidity3pm
# Pressure9am
# Pressure3pm
# Temp9am
# Temp3pm

# %%
df.to_csv("preprocessed_1.csv", index=False)

# %%
X = df.drop(["RainTomorrow", "Date"], axis=1)
Y = df["RainTomorrow"]

# %%
# scaler = RobustScaler()
# X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size =0.2, stratify = Y, random_state = 0)

# %%
y_train
# Out:
# 43447     0
# 140904    0
# 54615     0
# 109793    0
# 74462     0
#          ..
# 106567    0
# 52791     1
# 56339     0
# 82299     1
# 115175    0
# Name: RainTomorrow, Length: 116368, dtype: uint8

# %%
sm=SMOTE(random_state=0)
X_train_res, y_train_res = sm.fit_resample(X_train, y_train)
print("The number of classes before fit {}".format(Counter(y_train)))
print("The number of classes after fit {}".format(Counter(y_train_res)))
# Out:
# The number of classes before fit Counter({0: 90866, 1: 25502})
# The number of classes after fit Counter({0: 90866, 1: 90866})

# %%
cat = CatBoostClassifier(iterations=2000, eval_metric = "AUC")
cat.fit(X_train_res, y_train_res)
# Out:
# Learning rate set to 0.050311
# 0:	total: 214ms	remaining: 7m 7s
# 1:	total: 250ms	remaining: 4m 9s
# 2:	total: 279ms	remaining: 3m 5s
# 3:	total: 312ms	remaining: 2m 35s
# 4:	total: 341ms	remaining: 2m 15s
# 5:	total: 371ms	remaining: 2m 3s
# 6:	total: 402ms	remaining: 1m 54s
# 7:	total: 435ms	remaining: 1m 48s
# 8:	total: 463ms	remaining: 1m 42s
# 9:	total: 487ms	remaining: 1m 36s
# 10:	total: 513ms	remaining: 1m 32s
# 11:	total: 542ms	remaining: 1m 29s
# 12:	total: 568ms	remaining: 1m 26s
# 13:	total: 591ms	remaining: 1m 23s
# 14:	total: 617ms	remaining: 1m 21s
# 15:	total: 640ms	remaining: 1m 19s
# 16:	total: 666ms	remaining: 1m 17s
# 17:	total: 688ms	remaining: 1m 15s
# 18:	total: 712ms	remaining: 1m 14s
# 19:	total: 736ms	remaining: 1m 12s
# 20:	total: 762ms	remaining: 1m 11s
# 21:	total: 786ms	remaining: 1m 10s
# 22:	total: 817ms	remaining: 1m 10s
# 23:	total: 847ms	remaining: 1m 9s
# 24:	total: 874ms	remaining: 1m 9s
# 25:	total: 898ms	remaining: 1m 8s
# 26:	total: 927ms	remaining: 1m 7s
# 27:	total: 956ms	remaining: 1m 7s
# 28:	total: 983ms	remaining: 1m 6s
# 29:	total: 1.01s	remaining: 1m 6s
# 30:	total: 1.04s	remaining: 1m 5s
# 31:	total: 1.07s	remaining: 1m 5s
# 32:	total: 1.1s	remaining: 1m 5s
# 33:	total: 1.13s	remaining: 1m 5s
# 34:	total: 1.15s	remaining: 1m 4s
# 35:	total: 1.18s	remaining: 1m 4s
# 36:	total: 1.21s	remaining: 1m 4s
# 37:	total: 1.24s	remaining: 1m 3s
# 38:	total: 1.27s	remaining: 1m 4s
# 39:	total: 1.3s	remaining: 1m 3s
# 40:	total: 1.33s	remaining: 1m 3s
# 41:	total: 1.41s	remaining: 1m 5s
# 42:	total: 1.45s	remaining: 1m 6s
# 43:	total: 1.48s	remaining: 1m 5s
# 44:	total: 1.51s	remaining: 1m 5s
# 45:	total: 1.54s	remaining: 1m 5s
# 46:	total: 1.57s	remaining: 1m 5s
# 47:	total: 1.59s	remaining: 1m 4s
# 48:	total: 1.61s	remaining: 1m 4s
# 49:	total: 1.64s	remaining: 1m 4s
# 50:	total: 1.66s	remaining: 1m 3s
# 51:	total: 1.68s	remaining: 1m 3s
# 52:	total: 1.71s	remaining: 1m 2s
# 53:	total: 1.73s	remaining: 1m 2s
# 54:	total: 1.75s	remaining: 1m 1s
# 55:	total: 1.77s	remaining: 1m 1s
# 56:	total: 1.79s	remaining: 1m 1s
# 57:	total: 1.81s	remaining: 1m
# 58:	total: 1.84s	remaining: 1m
# 59:	total: 1.86s	remaining: 1m
# 60:	total: 1.89s	remaining: 1m
# 61:	total: 1.91s	remaining: 59.8s
# 62:	total: 1.93s	remaining: 59.5s
# 63:	total: 1.96s	remaining: 59.1s
# 64:	total: 1.98s	remaining: 58.8s
# 65:	total: 2s	remaining: 58.5s
# 66:	total: 2.02s	remaining: 58.2s
# 67:	total: 2.04s	remaining: 57.9s
# 68:	total: 2.06s	remaining: 57.6s
# 69:	total: 2.08s	remaining: 57.4s
# 70:	total: 2.1s	remaining: 57.1s
# 71:	total: 2.12s	remaining: 56.8s
# 72:	total: 2.14s	remaining: 56.6s
# 73:	total: 2.16s	remaining: 56.3s
# 74:	total: 2.19s	remaining: 56.2s
# 75:	total: 2.21s	remaining: 56s
# 76:	total: 2.23s	remaining: 55.8s
# 77:	total: 2.26s	remaining: 55.6s
# 78:	total: 2.28s	remaining: 55.4s
# 79:	total: 2.3s	remaining: 55.2s
# 80:	total: 2.32s	remaining: 55s
# 81:	total: 2.34s	remaining: 54.8s
# 82:	total: 2.36s	remaining: 54.6s
# 83:	total: 2.38s	remaining: 54.4s
# 84:	total: 2.41s	remaining: 54.3s
# 85:	total: 2.43s	remaining: 54.1s
# 86:	total: 2.46s	remaining: 54s
# 87:	total: 2.48s	remaining: 53.9s
# 88:	total: 2.51s	remaining: 53.8s
# 89:	total: 2.53s	remaining: 53.7s
# 90:	total: 2.56s	remaining: 53.6s
# 91:	total: 2.58s	remaining: 53.5s
# 92:	total: 2.6s	remaining: 53.3s
# 93:	total: 2.62s	remaining: 53.2s
# 94:	total: 2.65s	remaining: 53.1s
# 95:	total: 2.67s	remaining: 53s
# 96:	total: 2.69s	remaining: 52.8s
# 97:	total: 2.71s	remaining: 52.6s
# 98:	total: 2.74s	remaining: 52.5s
# 99:	total: 2.76s	remaining: 52.5s
# 100:	total: 2.79s	remaining: 52.4s
# 101:	total: 2.81s	remaining: 52.3s
# 102:	total: 2.83s	remaining: 52.1s
# 103:	total: 2.85s	remaining: 52s
# 104:	total: 2.88s	remaining: 51.9s
# 105:	total: 2.9s	remaining: 51.8s
# 106:	total: 2.92s	remaining: 51.6s
# 107:	total: 2.94s	remaining: 51.5s
# 108:	total: 2.96s	remaining: 51.4s
# 109:	total: 2.98s	remaining: 51.3s
# 110:	total: 3.01s	remaining: 51.2s
# 111:	total: 3.03s	remaining: 51.2s
# 112:	total: 3.06s	remaining: 51.1s
# 113:	total: 3.09s	remaining: 51.1s
# 114:	total: 3.11s	remaining: 51s
# 115:	total: 3.14s	remaining: 51s
# 116:	total: 3.17s	remaining: 50.9s
# 117:	total: 3.19s	remaining: 51s
# 118:	total: 3.22s	remaining: 51s
# 119:	total: 3.25s	remaining: 50.9s
# 120:	total: 3.27s	remaining: 50.9s
# 121:	total: 3.3s	remaining: 50.8s
# 122:	total: 3.33s	remaining: 50.8s
# 123:	total: 3.35s	remaining: 50.7s
# 124:	total: 3.38s	remaining: 50.6s
# 125:	total: 3.4s	remaining: 50.6s
# 126:	total: 3.43s	remaining: 50.5s
# 127:	total: 3.45s	remaining: 50.5s
# 128:	total: 3.47s	remaining: 50.4s
# 129:	total: 3.5s	remaining: 50.3s
# 130:	total: 3.52s	remaining: 50.2s
# 131:	total: 3.56s	remaining: 50.3s
# 132:	total: 3.58s	remaining: 50.3s
# 133:	total: 3.62s	remaining: 50.4s
# 134:	total: 3.65s	remaining: 50.4s
# 135:	total: 3.68s	remaining: 50.4s
# 136:	total: 3.71s	remaining: 50.4s
# 137:	total: 3.74s	remaining: 50.4s
# 138:	total: 3.76s	remaining: 50.3s
# 139:	total: 3.78s	remaining: 50.3s
# 140:	total: 3.81s	remaining: 50.2s
# 141:	total: 3.83s	remaining: 50.2s
# 142:	total: 3.87s	remaining: 50.2s
# 143:	total: 3.89s	remaining: 50.2s
# 144:	total: 3.92s	remaining: 50.2s
# 145:	total: 3.94s	remaining: 50.1s
# 146:	total: 3.97s	remaining: 50.1s
# 147:	total: 4s	remaining: 50.1s
# 148:	total: 4.03s	remaining: 50s
# 149:	total: 4.05s	remaining: 50s
# 150:	total: 4.09s	remaining: 50.1s
# 151:	total: 4.12s	remaining: 50.1s
# 152:	total: 4.14s	remaining: 50s
# 153:	total: 4.17s	remaining: 50s
# 154:	total: 4.2s	remaining: 49.9s
# 155:	total: 4.22s	remaining: 49.9s
# 156:	total: 4.24s	remaining: 49.8s
# 157:	total: 4.27s	remaining: 49.7s
# 158:	total: 4.29s	remaining: 49.7s
# 159:	total: 4.32s	remaining: 49.6s
# 160:	total: 4.34s	remaining: 49.5s
# 161:	total: 4.36s	remaining: 49.4s
# 162:	total: 4.38s	remaining: 49.3s
# 163:	total: 4.4s	remaining: 49.2s
# 164:	total: 4.42s	remaining: 49.2s
# 165:	total: 4.44s	remaining: 49.1s
# 166:	total: 4.46s	remaining: 49s
# 167:	total: 4.49s	remaining: 49s
# 168:	total: 4.52s	remaining: 48.9s
# 169:	total: 4.54s	remaining: 48.9s
# 170:	total: 4.57s	remaining: 48.8s
# 171:	total: 4.59s	remaining: 48.8s
# 172:	total: 4.61s	remaining: 48.7s
# 173:	total: 4.63s	remaining: 48.6s
# 174:	total: 4.66s	remaining: 48.6s
# 175:	total: 4.68s	remaining: 48.5s
# 176:	total: 4.71s	remaining: 48.5s
# 177:	total: 4.73s	remaining: 48.4s
# 178:	total: 4.75s	remaining: 48.4s
# 179:	total: 4.78s	remaining: 48.3s
# 180:	total: 4.8s	remaining: 48.2s
# 181:	total: 4.82s	remaining: 48.2s
# 182:	total: 4.84s	remaining: 48.1s
# 183:	total: 4.87s	remaining: 48s
# 184:	total: 4.89s	remaining: 48s
# 185:	total: 4.91s	remaining: 47.9s
# 186:	total: 4.93s	remaining: 47.8s
# 187:	total: 4.95s	remaining: 47.7s
# 188:	total: 4.97s	remaining: 47.7s
# 189:	total: 5s	remaining: 47.6s
# 190:	total: 5.02s	remaining: 47.6s
# 191:	total: 5.04s	remaining: 47.5s
# 192:	total: 5.07s	remaining: 47.5s
# 193:	total: 5.09s	remaining: 47.4s
# 194:	total: 5.11s	remaining: 47.3s
# 195:	total: 5.13s	remaining: 47.3s
# 196:	total: 5.16s	remaining: 47.2s
# 197:	total: 5.18s	remaining: 47.2s
# 198:	total: 5.2s	remaining: 47.1s
# 199:	total: 5.22s	remaining: 47s
# 200:	total: 5.25s	remaining: 47s
# 201:	total: 5.27s	remaining: 46.9s
# 202:	total: 5.29s	remaining: 46.8s
# 203:	total: 5.31s	remaining: 46.8s
# 204:	total: 5.33s	remaining: 46.7s
# 205:	total: 5.36s	remaining: 46.6s
# 206:	total: 5.38s	remaining: 46.6s
# 207:	total: 5.4s	remaining: 46.5s
# 208:	total: 5.42s	remaining: 46.5s
# 209:	total: 5.45s	remaining: 46.4s
# 210:	total: 5.47s	remaining: 46.4s
# 211:	total: 5.49s	remaining: 46.3s
# 212:	total: 5.52s	remaining: 46.3s
# 213:	total: 5.56s	remaining: 46.4s
# 214:	total: 5.59s	remaining: 46.4s
# 215:	total: 5.62s	remaining: 46.4s
# 216:	total: 5.64s	remaining: 46.3s
# 217:	total: 5.66s	remaining: 46.3s
# 218:	total: 5.68s	remaining: 46.2s
# 219:	total: 5.7s	remaining: 46.2s
# 220:	total: 5.73s	remaining: 46.1s
# 221:	total: 5.75s	remaining: 46s
# 222:	total: 5.77s	remaining: 46s
# 223:	total: 5.8s	remaining: 46s
# 224:	total: 5.83s	remaining: 46s
# 225:	total: 5.86s	remaining: 46s
# 226:	total: 5.89s	remaining: 46s
# 227:	total: 5.92s	remaining: 46s
# 228:	total: 5.95s	remaining: 46s
# 229:	total: 5.97s	remaining: 46s
# 230:	total: 6s	remaining: 45.9s
# 231:	total: 6.02s	remaining: 45.9s
# 232:	total: 6.04s	remaining: 45.8s
# 233:	total: 6.07s	remaining: 45.8s
# 234:	total: 6.09s	remaining: 45.8s
# 235:	total: 6.11s	remaining: 45.7s
# 236:	total: 6.14s	remaining: 45.7s
# 237:	total: 6.16s	remaining: 45.6s
# 238:	total: 6.19s	remaining: 45.6s
# 239:	total: 6.21s	remaining: 45.6s
# 240:	total: 6.23s	remaining: 45.5s
# 241:	total: 6.25s	remaining: 45.4s
# 242:	total: 6.28s	remaining: 45.4s
# 243:	total: 6.31s	remaining: 45.4s
# 244:	total: 6.33s	remaining: 45.4s
# 245:	total: 6.36s	remaining: 45.4s
# 246:	total: 6.38s	remaining: 45.3s
# 247:	total: 6.41s	remaining: 45.3s
# 248:	total: 6.43s	remaining: 45.2s
# 249:	total: 6.45s	remaining: 45.2s
# 250:	total: 6.48s	remaining: 45.2s
# 251:	total: 6.51s	remaining: 45.1s
# 252:	total: 6.53s	remaining: 45.1s
# 253:	total: 6.55s	remaining: 45s
# 254:	total: 6.58s	remaining: 45s
# 255:	total: 6.61s	remaining: 45s
# 256:	total: 6.64s	remaining: 45.1s
# 257:	total: 6.67s	remaining: 45.1s
# 258:	total: 6.7s	remaining: 45.1s
# 259:	total: 6.73s	remaining: 45s
# 260:	total: 6.76s	remaining: 45s
# 261:	total: 6.79s	remaining: 45s
# 262:	total: 6.81s	remaining: 45s
# 263:	total: 6.84s	remaining: 45s
# 264:	total: 6.87s	remaining: 44.9s
# 265:	total: 6.89s	remaining: 44.9s
# 266:	total: 6.92s	remaining: 44.9s
# 267:	total: 6.99s	remaining: 45.2s
# 268:	total: 7.02s	remaining: 45.2s
# 269:	total: 7.06s	remaining: 45.2s
# 270:	total: 7.09s	remaining: 45.2s
# 271:	total: 7.11s	remaining: 45.2s
# 272:	total: 7.14s	remaining: 45.2s
# 273:	total: 7.17s	remaining: 45.2s
# 274:	total: 7.2s	remaining: 45.1s
# 275:	total: 7.22s	remaining: 45.1s
# 276:	total: 7.24s	remaining: 45s
# 277:	total: 7.27s	remaining: 45s
# 278:	total: 7.29s	remaining: 45s
# 279:	total: 7.31s	remaining: 44.9s
# 280:	total: 7.34s	remaining: 44.9s
# 281:	total: 7.37s	remaining: 44.9s
# 282:	total: 7.39s	remaining: 44.8s
# 283:	total: 7.41s	remaining: 44.8s
# 284:	total: 7.43s	remaining: 44.7s
# 285:	total: 7.46s	remaining: 44.7s
# 286:	total: 7.48s	remaining: 44.7s
# 287:	total: 7.51s	remaining: 44.6s
# 288:	total: 7.53s	remaining: 44.6s
# 289:	total: 7.55s	remaining: 44.5s
# 290:	total: 7.58s	remaining: 44.5s
# 291:	total: 7.6s	remaining: 44.5s
# 292:	total: 7.65s	remaining: 44.6s
# 293:	total: 7.71s	remaining: 44.8s
# 294:	total: 7.75s	remaining: 44.8s
# 295:	total: 7.78s	remaining: 44.8s
# 296:	total: 7.8s	remaining: 44.8s
# 297:	total: 7.83s	remaining: 44.7s
# 298:	total: 7.85s	remaining: 44.7s
# 299:	total: 7.88s	remaining: 44.7s
# 300:	total: 7.91s	remaining: 44.6s
# 301:	total: 7.93s	remaining: 44.6s
# 302:	total: 7.96s	remaining: 44.6s
# 303:	total: 7.99s	remaining: 44.5s
# 304:	total: 8.01s	remaining: 44.5s
# 305:	total: 8.04s	remaining: 44.5s
# 306:	total: 8.07s	remaining: 44.5s
# 307:	total: 8.1s	remaining: 44.5s
# 308:	total: 8.13s	remaining: 44.5s
# 309:	total: 8.15s	remaining: 44.4s
# 310:	total: 8.18s	remaining: 44.4s
# 311:	total: 8.2s	remaining: 44.4s
# 312:	total: 8.23s	remaining: 44.4s
# 313:	total: 8.26s	remaining: 44.3s
# 314:	total: 8.29s	remaining: 44.3s
# 315:	total: 8.31s	remaining: 44.3s
# 316:	total: 8.34s	remaining: 44.3s
# 317:	total: 8.36s	remaining: 44.2s
# 318:	total: 8.39s	remaining: 44.2s
# 319:	total: 8.41s	remaining: 44.2s
# 320:	total: 8.44s	remaining: 44.1s
# 321:	total: 8.46s	remaining: 44.1s
# 322:	total: 8.49s	remaining: 44.1s
# 323:	total: 8.51s	remaining: 44s
# 324:	total: 8.54s	remaining: 44s
# 325:	total: 8.56s	remaining: 44s
# 326:	total: 8.59s	remaining: 43.9s
# 327:	total: 8.61s	remaining: 43.9s
# 328:	total: 8.63s	remaining: 43.8s
# 329:	total: 8.66s	remaining: 43.8s
# 330:	total: 8.68s	remaining: 43.8s
# 331:	total: 8.71s	remaining: 43.8s
# 332:	total: 8.73s	remaining: 43.7s
# 333:	total: 8.8s	remaining: 43.9s
# 334:	total: 8.83s	remaining: 43.9s
# 335:	total: 8.86s	remaining: 43.9s
# 336:	total: 8.88s	remaining: 43.8s
# 337:	total: 8.9s	remaining: 43.8s
# 338:	total: 8.93s	remaining: 43.8s
# 339:	total: 8.96s	remaining: 43.8s
# 340:	total: 8.99s	remaining: 43.7s
# 341:	total: 9.01s	remaining: 43.7s
# 342:	total: 9.03s	remaining: 43.6s
# 343:	total: 9.05s	remaining: 43.6s
# 344:	total: 9.08s	remaining: 43.5s
# 345:	total: 9.1s	remaining: 43.5s
# 346:	total: 9.12s	remaining: 43.5s
# 347:	total: 9.14s	remaining: 43.4s
# 348:	total: 9.17s	remaining: 43.4s
# 349:	total: 9.19s	remaining: 43.3s
# 350:	total: 9.22s	remaining: 43.3s
# 351:	total: 9.24s	remaining: 43.3s
# 352:	total: 9.26s	remaining: 43.2s
# 353:	total: 9.28s	remaining: 43.2s
# 354:	total: 9.3s	remaining: 43.1s
# 355:	total: 9.33s	remaining: 43.1s
# 356:	total: 9.35s	remaining: 43s
# 357:	total: 9.37s	remaining: 43s
# 358:	total: 9.39s	remaining: 42.9s
# 359:	total: 9.41s	remaining: 42.9s
# 360:	total: 9.43s	remaining: 42.8s
# 361:	total: 9.45s	remaining: 42.8s
# 362:	total: 9.47s	remaining: 42.7s
# 363:	total: 9.49s	remaining: 42.7s
# 364:	total: 9.52s	remaining: 42.6s
# 365:	total: 9.54s	remaining: 42.6s
# 366:	total: 9.56s	remaining: 42.5s
# 367:	total: 9.58s	remaining: 42.5s
# 368:	total: 9.6s	remaining: 42.4s
# 369:	total: 9.62s	remaining: 42.4s
# 370:	total: 9.64s	remaining: 42.4s
# 371:	total: 9.67s	remaining: 42.3s
# 372:	total: 9.69s	remaining: 42.3s
# 373:	total: 9.71s	remaining: 42.2s
# 374:	total: 9.73s	remaining: 42.2s
# 375:	total: 9.75s	remaining: 42.1s
# 376:	total: 9.77s	remaining: 42.1s
# 377:	total: 9.79s	remaining: 42s
# 378:	total: 9.81s	remaining: 42s
# 379:	total: 9.84s	remaining: 41.9s
# 380:	total: 9.86s	remaining: 41.9s
# 381:	total: 9.88s	remaining: 41.8s
# 382:	total: 9.9s	remaining: 41.8s
# 383:	total: 9.92s	remaining: 41.8s
# 384:	total: 9.94s	remaining: 41.7s
# 385:	total: 9.96s	remaining: 41.7s
# 386:	total: 9.98s	remaining: 41.6s
# 387:	total: 10s	remaining: 41.6s
# 388:	total: 10s	remaining: 41.5s
# 389:	total: 10s	remaining: 41.5s
# 390:	total: 10.1s	remaining: 41.4s
# 391:	total: 10.1s	remaining: 41.4s
# 392:	total: 10.1s	remaining: 41.3s
# 393:	total: 10.1s	remaining: 41.3s
# 394:	total: 10.2s	remaining: 41.3s
# 395:	total: 10.2s	remaining: 41.2s
# 396:	total: 10.2s	remaining: 41.2s
# 397:	total: 10.2s	remaining: 41.1s
# 398:	total: 10.2s	remaining: 41.1s
# 399:	total: 10.3s	remaining: 41s
# 400:	total: 10.3s	remaining: 41s
# 401:	total: 10.3s	remaining: 41s
# 402:	total: 10.3s	remaining: 40.9s
# 403:	total: 10.3s	remaining: 40.9s
# 404:	total: 10.4s	remaining: 40.9s
# 405:	total: 10.4s	remaining: 40.8s
# 406:	total: 10.4s	remaining: 40.8s
# 407:	total: 10.4s	remaining: 40.7s
# 408:	total: 10.5s	remaining: 40.7s
# 409:	total: 10.5s	remaining: 40.7s
# 410:	total: 10.5s	remaining: 40.7s
# 411:	total: 10.5s	remaining: 40.6s
# 412:	total: 10.6s	remaining: 40.6s
# 413:	total: 10.6s	remaining: 40.6s
# 414:	total: 10.6s	remaining: 40.6s
# 415:	total: 10.6s	remaining: 40.5s
# 416:	total: 10.7s	remaining: 40.5s
# 417:	total: 10.7s	remaining: 40.6s
# 418:	total: 10.7s	remaining: 40.5s
# 419:	total: 10.8s	remaining: 40.5s
# 420:	total: 10.8s	remaining: 40.5s
# 421:	total: 10.8s	remaining: 40.5s
# 422:	total: 10.8s	remaining: 40.4s
# 423:	total: 10.9s	remaining: 40.4s
# 424:	total: 10.9s	remaining: 40.4s
# 425:	total: 10.9s	remaining: 40.4s
# 426:	total: 11s	remaining: 40.4s
# 427:	total: 11s	remaining: 40.4s
# 428:	total: 11s	remaining: 40.3s
# 429:	total: 11s	remaining: 40.3s
# 430:	total: 11.1s	remaining: 40.3s
# 431:	total: 11.1s	remaining: 40.3s
# 432:	total: 11.1s	remaining: 40.2s
# 433:	total: 11.1s	remaining: 40.2s
# 434:	total: 11.2s	remaining: 40.2s
# 435:	total: 11.2s	remaining: 40.2s
# 436:	total: 11.2s	remaining: 40.1s
# 437:	total: 11.2s	remaining: 40.1s
# 438:	total: 11.3s	remaining: 40.1s
# 439:	total: 11.3s	remaining: 40.1s
# 440:	total: 11.3s	remaining: 40s
# 441:	total: 11.3s	remaining: 40s
# 442:	total: 11.4s	remaining: 40s
# 443:	total: 11.4s	remaining: 39.9s
# 444:	total: 11.4s	remaining: 39.9s
# 445:	total: 11.4s	remaining: 39.9s
# 446:	total: 11.5s	remaining: 39.9s
# 447:	total: 11.5s	remaining: 39.8s
# 448:	total: 11.5s	remaining: 39.8s
# 449:	total: 11.6s	remaining: 39.8s
# 450:	total: 11.6s	remaining: 39.8s
# 451:	total: 11.6s	remaining: 39.7s
# 452:	total: 11.6s	remaining: 39.7s
# 453:	total: 11.6s	remaining: 39.6s
# 454:	total: 11.7s	remaining: 39.6s
# 455:	total: 11.7s	remaining: 39.6s
# 456:	total: 11.7s	remaining: 39.5s
# 457:	total: 11.7s	remaining: 39.5s
# 458:	total: 11.8s	remaining: 39.5s
# 459:	total: 11.8s	remaining: 39.4s
# 460:	total: 11.8s	remaining: 39.4s
# 461:	total: 11.8s	remaining: 39.4s
# 462:	total: 11.9s	remaining: 39.4s
# 463:	total: 11.9s	remaining: 39.3s
# 464:	total: 11.9s	remaining: 39.3s
# 465:	total: 11.9s	remaining: 39.3s
# 466:	total: 12s	remaining: 39.2s
# 467:	total: 12s	remaining: 39.2s
# 468:	total: 12s	remaining: 39.2s
# 469:	total: 12s	remaining: 39.1s
# 470:	total: 12s	remaining: 39.1s
# 471:	total: 12.1s	remaining: 39.1s
# 472:	total: 12.1s	remaining: 39.1s
# 473:	total: 12.1s	remaining: 39.1s
# 474:	total: 12.2s	remaining: 39s
# 475:	total: 12.2s	remaining: 39s
# 476:	total: 12.2s	remaining: 39s
# 477:	total: 12.2s	remaining: 38.9s
# 478:	total: 12.3s	remaining: 38.9s
# 479:	total: 12.3s	remaining: 38.9s
# 480:	total: 12.3s	remaining: 38.8s
# 481:	total: 12.3s	remaining: 38.8s
# 482:	total: 12.3s	remaining: 38.8s
# 483:	total: 12.4s	remaining: 38.7s
# 484:	total: 12.4s	remaining: 38.7s
# 485:	total: 12.4s	remaining: 38.7s
# 486:	total: 12.4s	remaining: 38.6s
# 487:	total: 12.5s	remaining: 38.6s
# 488:	total: 12.5s	remaining: 38.6s
# 489:	total: 12.5s	remaining: 38.6s
# 490:	total: 12.5s	remaining: 38.5s
# 491:	total: 12.6s	remaining: 38.5s
# 492:	total: 12.6s	remaining: 38.5s
# 493:	total: 12.6s	remaining: 38.4s
# 494:	total: 12.6s	remaining: 38.4s
# 495:	total: 12.7s	remaining: 38.4s
# 496:	total: 12.7s	remaining: 38.3s
# 497:	total: 12.7s	remaining: 38.3s
# 498:	total: 12.7s	remaining: 38.2s
# 499:	total: 12.7s	remaining: 38.2s
# 500:	total: 12.8s	remaining: 38.2s
# 501:	total: 12.8s	remaining: 38.1s
# 502:	total: 12.8s	remaining: 38.1s
# 503:	total: 12.8s	remaining: 38s
# 504:	total: 12.8s	remaining: 38s
# 505:	total: 12.9s	remaining: 38s
# 506:	total: 12.9s	remaining: 37.9s
# 507:	total: 12.9s	remaining: 37.9s
# 508:	total: 12.9s	remaining: 37.9s
# 509:	total: 12.9s	remaining: 37.8s
# 510:	total: 13s	remaining: 37.8s
# 511:	total: 13s	remaining: 37.7s
# 512:	total: 13s	remaining: 37.7s
# 513:	total: 13s	remaining: 37.7s
# 514:	total: 13s	remaining: 37.6s
# 515:	total: 13.1s	remaining: 37.6s
# 516:	total: 13.1s	remaining: 37.5s
# 517:	total: 13.1s	remaining: 37.5s
# 518:	total: 13.1s	remaining: 37.5s
# 519:	total: 13.1s	remaining: 37.4s
# 520:	total: 13.2s	remaining: 37.4s
# 521:	total: 13.2s	remaining: 37.3s
# 522:	total: 13.2s	remaining: 37.3s
# 523:	total: 13.2s	remaining: 37.3s
# 524:	total: 13.3s	remaining: 37.2s
# 525:	total: 13.3s	remaining: 37.2s
# 526:	total: 13.3s	remaining: 37.2s
# 527:	total: 13.3s	remaining: 37.1s
# 528:	total: 13.3s	remaining: 37.1s
# 529:	total: 13.4s	remaining: 37.1s
# 530:	total: 13.4s	remaining: 37s
# 531:	total: 13.4s	remaining: 37s
# 532:	total: 13.4s	remaining: 37s
# 533:	total: 13.4s	remaining: 36.9s
# 534:	total: 13.5s	remaining: 36.9s
# 535:	total: 13.5s	remaining: 36.8s
# 536:	total: 13.5s	remaining: 36.8s
# 537:	total: 13.5s	remaining: 36.8s
# 538:	total: 13.6s	remaining: 36.7s
# 539:	total: 13.6s	remaining: 36.7s
# 540:	total: 13.6s	remaining: 36.7s
# 541:	total: 13.6s	remaining: 36.6s
# 542:	total: 13.6s	remaining: 36.6s
# 543:	total: 13.7s	remaining: 36.5s
# 544:	total: 13.7s	remaining: 36.5s
# 545:	total: 13.7s	remaining: 36.5s
# 546:	total: 13.7s	remaining: 36.5s
# 547:	total: 13.8s	remaining: 36.4s
# 548:	total: 13.8s	remaining: 36.4s
# 549:	total: 13.8s	remaining: 36.4s
# 550:	total: 13.8s	remaining: 36.3s
# 551:	total: 13.8s	remaining: 36.3s
# 552:	total: 13.9s	remaining: 36.3s
# 553:	total: 13.9s	remaining: 36.2s
# 554:	total: 13.9s	remaining: 36.2s
# 555:	total: 13.9s	remaining: 36.2s
# 556:	total: 13.9s	remaining: 36.1s
# 557:	total: 14s	remaining: 36.1s
# 558:	total: 14s	remaining: 36.1s
# 559:	total: 14s	remaining: 36s
# 560:	total: 14s	remaining: 36s
# 561:	total: 14.1s	remaining: 36s
# 562:	total: 14.1s	remaining: 35.9s
# 563:	total: 14.1s	remaining: 35.9s
# 564:	total: 14.1s	remaining: 35.9s
# 565:	total: 14.1s	remaining: 35.8s
# 566:	total: 14.2s	remaining: 35.8s
# 567:	total: 14.2s	remaining: 35.8s
# 568:	total: 14.2s	remaining: 35.7s
# 569:	total: 14.2s	remaining: 35.7s
# 570:	total: 14.3s	remaining: 35.7s
# 571:	total: 14.3s	remaining: 35.6s
# 572:	total: 14.3s	remaining: 35.6s
# 573:	total: 14.3s	remaining: 35.6s
# 574:	total: 14.3s	remaining: 35.5s
# 575:	total: 14.4s	remaining: 35.5s
# 576:	total: 14.4s	remaining: 35.5s
# 577:	total: 14.4s	remaining: 35.4s
# 578:	total: 14.4s	remaining: 35.4s
# 579:	total: 14.5s	remaining: 35.4s
# 580:	total: 14.5s	remaining: 35.3s
# 581:	total: 14.5s	remaining: 35.3s
# 582:	total: 14.5s	remaining: 35.3s
# 583:	total: 14.5s	remaining: 35.2s
# 584:	total: 14.6s	remaining: 35.2s
# 585:	total: 14.6s	remaining: 35.2s
# 586:	total: 14.6s	remaining: 35.1s
# 587:	total: 14.6s	remaining: 35.1s
# 588:	total: 14.6s	remaining: 35.1s
# 589:	total: 14.7s	remaining: 35s
# 590:	total: 14.7s	remaining: 35s
# 591:	total: 14.7s	remaining: 35s
# 592:	total: 14.7s	remaining: 34.9s
# 593:	total: 14.7s	remaining: 34.9s
# 594:	total: 14.8s	remaining: 34.9s
# 595:	total: 14.8s	remaining: 34.8s
# 596:	total: 14.8s	remaining: 34.8s
# 597:	total: 14.8s	remaining: 34.8s
# 598:	total: 14.8s	remaining: 34.7s
# 599:	total: 14.9s	remaining: 34.7s
# 600:	total: 14.9s	remaining: 34.7s
# 601:	total: 14.9s	remaining: 34.6s
# 602:	total: 14.9s	remaining: 34.6s
# 603:	total: 15s	remaining: 34.6s
# 604:	total: 15s	remaining: 34.5s
# 605:	total: 15s	remaining: 34.5s
# 606:	total: 15s	remaining: 34.5s
# 607:	total: 15s	remaining: 34.4s
# 608:	total: 15.1s	remaining: 34.4s
# 609:	total: 15.1s	remaining: 34.4s
# 610:	total: 15.1s	remaining: 34.3s
# 611:	total: 15.1s	remaining: 34.3s
# 612:	total: 15.2s	remaining: 34.3s
# 613:	total: 15.2s	remaining: 34.2s
# 614:	total: 15.2s	remaining: 34.2s
# 615:	total: 15.2s	remaining: 34.2s
# 616:	total: 15.2s	remaining: 34.1s
# 617:	total: 15.3s	remaining: 34.1s
# 618:	total: 15.3s	remaining: 34.1s
# 619:	total: 15.3s	remaining: 34.1s
# 620:	total: 15.3s	remaining: 34s
# 621:	total: 15.3s	remaining: 34s
# 622:	total: 15.4s	remaining: 33.9s
# 623:	total: 15.4s	remaining: 33.9s
# 624:	total: 15.4s	remaining: 33.9s
# 625:	total: 15.4s	remaining: 33.9s
# 626:	total: 15.4s	remaining: 33.8s
# 627:	total: 15.5s	remaining: 33.8s
# 628:	total: 15.5s	remaining: 33.8s
# 629:	total: 15.5s	remaining: 33.7s
# 630:	total: 15.5s	remaining: 33.7s
# 631:	total: 15.6s	remaining: 33.7s
# 632:	total: 15.6s	remaining: 33.6s
# 633:	total: 15.6s	remaining: 33.6s
# 634:	total: 15.6s	remaining: 33.6s
# 635:	total: 15.6s	remaining: 33.5s
# 636:	total: 15.7s	remaining: 33.5s
# 637:	total: 15.7s	remaining: 33.5s
# 638:	total: 15.7s	remaining: 33.4s
# 639:	total: 15.7s	remaining: 33.4s
# 640:	total: 15.7s	remaining: 33.4s
# 641:	total: 15.8s	remaining: 33.3s
# 642:	total: 15.8s	remaining: 33.3s
# 643:	total: 15.8s	remaining: 33.3s
# 644:	total: 15.8s	remaining: 33.2s
# 645:	total: 15.8s	remaining: 33.2s
# 646:	total: 15.9s	remaining: 33.2s
# 647:	total: 15.9s	remaining: 33.1s
# 648:	total: 15.9s	remaining: 33.1s
# 649:	total: 15.9s	remaining: 33.1s
# 650:	total: 16s	remaining: 33.1s
# 651:	total: 16s	remaining: 33s
# 652:	total: 16s	remaining: 33s
# 653:	total: 16s	remaining: 33s
# 654:	total: 16s	remaining: 32.9s
# 655:	total: 16.1s	remaining: 32.9s
# 656:	total: 16.1s	remaining: 32.9s
# 657:	total: 16.1s	remaining: 32.8s
# 658:	total: 16.1s	remaining: 32.8s
# 659:	total: 16.1s	remaining: 32.8s
# 660:	total: 16.2s	remaining: 32.7s
# 661:	total: 16.2s	remaining: 32.7s
# 662:	total: 16.2s	remaining: 32.7s
# 663:	total: 16.2s	remaining: 32.6s
# 664:	total: 16.2s	remaining: 32.6s
# 665:	total: 16.3s	remaining: 32.6s
# 666:	total: 16.3s	remaining: 32.5s
# 667:	total: 16.3s	remaining: 32.5s
# 668:	total: 16.3s	remaining: 32.5s
# 669:	total: 16.3s	remaining: 32.5s
# 670:	total: 16.4s	remaining: 32.4s
# 671:	total: 16.4s	remaining: 32.4s
# 672:	total: 16.4s	remaining: 32.4s
# 673:	total: 16.4s	remaining: 32.3s
# 674:	total: 16.5s	remaining: 32.3s
# 675:	total: 16.5s	remaining: 32.3s
# 676:	total: 16.5s	remaining: 32.2s
# 677:	total: 16.5s	remaining: 32.2s
# 678:	total: 16.5s	remaining: 32.2s
# 679:	total: 16.6s	remaining: 32.2s
# 680:	total: 16.6s	remaining: 32.1s
# 681:	total: 16.6s	remaining: 32.1s
# 682:	total: 16.6s	remaining: 32.1s
# 683:	total: 16.6s	remaining: 32s
# 684:	total: 16.7s	remaining: 32s
# 685:	total: 16.7s	remaining: 32s
# 686:	total: 16.7s	remaining: 31.9s
# 687:	total: 16.7s	remaining: 31.9s
# 688:	total: 16.8s	remaining: 31.9s
# 689:	total: 16.8s	remaining: 31.8s
# 690:	total: 16.8s	remaining: 31.8s
# 691:	total: 16.8s	remaining: 31.8s
# 692:	total: 16.8s	remaining: 31.8s
# 693:	total: 16.9s	remaining: 31.7s
# 694:	total: 16.9s	remaining: 31.7s
# 695:	total: 16.9s	remaining: 31.7s
# 696:	total: 16.9s	remaining: 31.6s
# 697:	total: 16.9s	remaining: 31.6s
# 698:	total: 17s	remaining: 31.6s
# 699:	total: 17s	remaining: 31.5s
# 700:	total: 17s	remaining: 31.5s
# 701:	total: 17s	remaining: 31.5s
# 702:	total: 17s	remaining: 31.4s
# 703:	total: 17.1s	remaining: 31.4s
# 704:	total: 17.1s	remaining: 31.4s
# 705:	total: 17.1s	remaining: 31.4s
# 706:	total: 17.1s	remaining: 31.3s
# 707:	total: 17.2s	remaining: 31.3s
# 708:	total: 17.2s	remaining: 31.3s
# 709:	total: 17.2s	remaining: 31.3s
# 710:	total: 17.2s	remaining: 31.2s
# 711:	total: 17.2s	remaining: 31.2s
# 712:	total: 17.3s	remaining: 31.2s
# 713:	total: 17.3s	remaining: 31.1s
# 714:	total: 17.3s	remaining: 31.1s
# 715:	total: 17.3s	remaining: 31.1s
# 716:	total: 17.3s	remaining: 31s
# 717:	total: 17.4s	remaining: 31s
# 718:	total: 17.4s	remaining: 31s
# 719:	total: 17.4s	remaining: 31s
# 720:	total: 17.4s	remaining: 30.9s
# 721:	total: 17.5s	remaining: 30.9s
# 722:	total: 17.5s	remaining: 30.9s
# 723:	total: 17.5s	remaining: 30.8s
# 724:	total: 17.5s	remaining: 30.8s
# 725:	total: 17.5s	remaining: 30.8s
# 726:	total: 17.6s	remaining: 30.8s
# 727:	total: 17.6s	remaining: 30.7s
# 728:	total: 17.6s	remaining: 30.7s
# 729:	total: 17.6s	remaining: 30.7s
# 730:	total: 17.6s	remaining: 30.6s
# 731:	total: 17.7s	remaining: 30.6s
# 732:	total: 17.7s	remaining: 30.6s
# 733:	total: 17.7s	remaining: 30.5s
# 734:	total: 17.7s	remaining: 30.5s
# 735:	total: 17.8s	remaining: 30.5s
# 736:	total: 17.8s	remaining: 30.5s
# 737:	total: 17.8s	remaining: 30.4s
# 738:	total: 17.8s	remaining: 30.4s
# 739:	total: 17.8s	remaining: 30.4s
# 740:	total: 17.9s	remaining: 30.3s
# 741:	total: 17.9s	remaining: 30.3s
# 742:	total: 17.9s	remaining: 30.3s
# 743:	total: 17.9s	remaining: 30.2s
# 744:	total: 17.9s	remaining: 30.2s
# 745:	total: 18s	remaining: 30.2s
# 746:	total: 18s	remaining: 30.2s
# 747:	total: 18s	remaining: 30.2s
# 748:	total: 18s	remaining: 30.1s
# 749:	total: 18.1s	remaining: 30.1s
# 750:	total: 18.1s	remaining: 30.1s
# 751:	total: 18.1s	remaining: 30s
# 752:	total: 18.1s	remaining: 30s
# 753:	total: 18.1s	remaining: 30s
# 754:	total: 18.2s	remaining: 30s
# 755:	total: 18.2s	remaining: 29.9s
# 756:	total: 18.2s	remaining: 29.9s
# 757:	total: 18.2s	remaining: 29.9s
# 758:	total: 18.2s	remaining: 29.8s
# 759:	total: 18.3s	remaining: 29.8s
# 760:	total: 18.3s	remaining: 29.8s
# 761:	total: 18.3s	remaining: 29.7s
# 762:	total: 18.3s	remaining: 29.7s
# 763:	total: 18.3s	remaining: 29.7s
# 764:	total: 18.4s	remaining: 29.7s
# 765:	total: 18.4s	remaining: 29.6s
# 766:	total: 18.4s	remaining: 29.6s
# 767:	total: 18.4s	remaining: 29.6s
# 768:	total: 18.5s	remaining: 29.5s
# 769:	total: 18.5s	remaining: 29.5s
# 770:	total: 18.5s	remaining: 29.5s
# 771:	total: 18.5s	remaining: 29.5s
# 772:	total: 18.5s	remaining: 29.4s
# 773:	total: 18.6s	remaining: 29.4s
# 774:	total: 18.6s	remaining: 29.4s
# 775:	total: 18.6s	remaining: 29.3s
# 776:	total: 18.6s	remaining: 29.3s
# 777:	total: 18.6s	remaining: 29.3s
# 778:	total: 18.7s	remaining: 29.2s
# 779:	total: 18.7s	remaining: 29.2s
# 780:	total: 18.7s	remaining: 29.2s
# 781:	total: 18.7s	remaining: 29.2s
# 782:	total: 18.7s	remaining: 29.1s
# 783:	total: 18.8s	remaining: 29.1s
# 784:	total: 18.8s	remaining: 29.1s
# 785:	total: 18.8s	remaining: 29s
# 786:	total: 18.8s	remaining: 29s
# 787:	total: 18.8s	remaining: 29s
# 788:	total: 18.9s	remaining: 28.9s
# 789:	total: 18.9s	remaining: 28.9s
# 790:	total: 18.9s	remaining: 28.9s
# 791:	total: 18.9s	remaining: 28.9s
# 792:	total: 18.9s	remaining: 28.8s
# 793:	total: 19s	remaining: 28.8s
# 794:	total: 19s	remaining: 28.8s
# 795:	total: 19s	remaining: 28.7s
# 796:	total: 19s	remaining: 28.7s
# 797:	total: 19s	remaining: 28.7s
# 798:	total: 19.1s	remaining: 28.7s
# 799:	total: 19.1s	remaining: 28.6s
# 800:	total: 19.1s	remaining: 28.6s
# 801:	total: 19.1s	remaining: 28.6s
# 802:	total: 19.1s	remaining: 28.5s
# 803:	total: 19.2s	remaining: 28.5s
# 804:	total: 19.2s	remaining: 28.5s
# 805:	total: 19.2s	remaining: 28.4s
# 806:	total: 19.2s	remaining: 28.4s
# 807:	total: 19.2s	remaining: 28.4s
# 808:	total: 19.3s	remaining: 28.4s
# 809:	total: 19.3s	remaining: 28.3s
# 810:	total: 19.3s	remaining: 28.3s
# 811:	total: 19.3s	remaining: 28.3s
# 812:	total: 19.3s	remaining: 28.2s
# 813:	total: 19.4s	remaining: 28.2s
# 814:	total: 19.4s	remaining: 28.2s
# 815:	total: 19.4s	remaining: 28.2s
# 816:	total: 19.4s	remaining: 28.1s
# 817:	total: 19.5s	remaining: 28.1s
# 818:	total: 19.5s	remaining: 28.1s
# 819:	total: 19.5s	remaining: 28.1s
# 820:	total: 19.5s	remaining: 28s
# 821:	total: 19.5s	remaining: 28s
# 822:	total: 19.6s	remaining: 28s
# 823:	total: 19.6s	remaining: 27.9s
# 824:	total: 19.6s	remaining: 27.9s
# 825:	total: 19.6s	remaining: 27.9s
# 826:	total: 19.6s	remaining: 27.9s
# 827:	total: 19.7s	remaining: 27.8s
# 828:	total: 19.7s	remaining: 27.8s
# 829:	total: 19.7s	remaining: 27.8s
# 830:	total: 19.7s	remaining: 27.7s
# 831:	total: 19.7s	remaining: 27.7s
# 832:	total: 19.8s	remaining: 27.7s
# 833:	total: 19.8s	remaining: 27.6s
# 834:	total: 19.8s	remaining: 27.6s
# 835:	total: 19.8s	remaining: 27.6s
# 836:	total: 19.8s	remaining: 27.6s
# 837:	total: 19.9s	remaining: 27.5s
# 838:	total: 19.9s	remaining: 27.5s
# 839:	total: 19.9s	remaining: 27.5s
# 840:	total: 19.9s	remaining: 27.5s
# 841:	total: 19.9s	remaining: 27.4s
# 842:	total: 20s	remaining: 27.4s
# 843:	total: 20s	remaining: 27.4s
# 844:	total: 20s	remaining: 27.3s
# 845:	total: 20s	remaining: 27.3s
# 846:	total: 20s	remaining: 27.3s
# 847:	total: 20.1s	remaining: 27.3s
# 848:	total: 20.1s	remaining: 27.2s
# 849:	total: 20.1s	remaining: 27.2s
# 850:	total: 20.1s	remaining: 27.2s
# 851:	total: 20.1s	remaining: 27.1s
# 852:	total: 20.2s	remaining: 27.1s
# 853:	total: 20.2s	remaining: 27.1s
# 854:	total: 20.2s	remaining: 27s
# 855:	total: 20.2s	remaining: 27s
# 856:	total: 20.2s	remaining: 27s
# 857:	total: 20.3s	remaining: 27s
# 858:	total: 20.3s	remaining: 26.9s
# 859:	total: 20.3s	remaining: 26.9s
# 860:	total: 20.3s	remaining: 26.9s
# 861:	total: 20.3s	remaining: 26.9s
# 862:	total: 20.4s	remaining: 26.8s
# 863:	total: 20.4s	remaining: 26.8s
# 864:	total: 20.4s	remaining: 26.8s
# 865:	total: 20.4s	remaining: 26.7s
# 866:	total: 20.4s	remaining: 26.7s
# 867:	total: 20.5s	remaining: 26.7s
# 868:	total: 20.5s	remaining: 26.7s
# 869:	total: 20.5s	remaining: 26.6s
# 870:	total: 20.5s	remaining: 26.6s
# 871:	total: 20.5s	remaining: 26.6s
# 872:	total: 20.6s	remaining: 26.6s
# 873:	total: 20.6s	remaining: 26.5s
# 874:	total: 20.6s	remaining: 26.5s
# 875:	total: 20.6s	remaining: 26.5s
# 876:	total: 20.6s	remaining: 26.4s
# 877:	total: 20.7s	remaining: 26.4s
# 878:	total: 20.7s	remaining: 26.4s
# 879:	total: 20.7s	remaining: 26.4s
# 880:	total: 20.7s	remaining: 26.3s
# 881:	total: 20.7s	remaining: 26.3s
# 882:	total: 20.8s	remaining: 26.3s
# 883:	total: 20.8s	remaining: 26.2s
# 884:	total: 20.8s	remaining: 26.2s
# 885:	total: 20.8s	remaining: 26.2s
# 886:	total: 20.9s	remaining: 26.2s
# 887:	total: 20.9s	remaining: 26.1s
# 888:	total: 20.9s	remaining: 26.1s
# 889:	total: 20.9s	remaining: 26.1s
# 890:	total: 20.9s	remaining: 26.1s
# 891:	total: 21s	remaining: 26s
# 892:	total: 21s	remaining: 26s
# 893:	total: 21s	remaining: 26s
# 894:	total: 21s	remaining: 26s
# 895:	total: 21s	remaining: 25.9s
# 896:	total: 21.1s	remaining: 25.9s
# 897:	total: 21.1s	remaining: 25.9s
# 898:	total: 21.1s	remaining: 25.8s
# 899:	total: 21.1s	remaining: 25.8s
# 900:	total: 21.1s	remaining: 25.8s
# 901:	total: 21.2s	remaining: 25.8s
# 902:	total: 21.2s	remaining: 25.7s
# 903:	total: 21.2s	remaining: 25.7s
# 904:	total: 21.2s	remaining: 25.7s
# 905:	total: 21.2s	remaining: 25.7s
# 906:	total: 21.3s	remaining: 25.6s
# 907:	total: 21.3s	remaining: 25.6s
# 908:	total: 21.3s	remaining: 25.6s
# 909:	total: 21.3s	remaining: 25.6s
# 910:	total: 21.4s	remaining: 25.5s
# 911:	total: 21.4s	remaining: 25.5s
# 912:	total: 21.4s	remaining: 25.5s
# 913:	total: 21.4s	remaining: 25.4s
# 914:	total: 21.4s	remaining: 25.4s
# 915:	total: 21.5s	remaining: 25.4s
# 916:	total: 21.5s	remaining: 25.4s
# 917:	total: 21.5s	remaining: 25.3s
# 918:	total: 21.5s	remaining: 25.3s
# 919:	total: 21.5s	remaining: 25.3s
# 920:	total: 21.6s	remaining: 25.3s
# 921:	total: 21.6s	remaining: 25.2s
# 922:	total: 21.6s	remaining: 25.2s
# 923:	total: 21.6s	remaining: 25.2s
# 924:	total: 21.6s	remaining: 25.2s
# 925:	total: 21.7s	remaining: 25.1s
# 926:	total: 21.7s	remaining: 25.1s
# 927:	total: 21.7s	remaining: 25.1s
# 928:	total: 21.7s	remaining: 25s
# 929:	total: 21.7s	remaining: 25s
# 930:	total: 21.8s	remaining: 25s
# 931:	total: 21.8s	remaining: 25s
# 932:	total: 21.8s	remaining: 24.9s
# 933:	total: 21.8s	remaining: 24.9s
# 934:	total: 21.8s	remaining: 24.9s
# 935:	total: 21.9s	remaining: 24.9s
# 936:	total: 21.9s	remaining: 24.8s
# 937:	total: 21.9s	remaining: 24.8s
# 938:	total: 21.9s	remaining: 24.8s
# 939:	total: 21.9s	remaining: 24.7s
# 940:	total: 22s	remaining: 24.7s
# 941:	total: 22s	remaining: 24.7s
# 942:	total: 22s	remaining: 24.7s
# 943:	total: 22s	remaining: 24.6s
# 944:	total: 22.1s	remaining: 24.7s
# 945:	total: 22.1s	remaining: 24.6s
# 946:	total: 22.1s	remaining: 24.6s
# 947:	total: 22.2s	remaining: 24.6s
# 948:	total: 22.2s	remaining: 24.6s
# 949:	total: 22.2s	remaining: 24.5s
# 950:	total: 22.2s	remaining: 24.5s
# 951:	total: 22.2s	remaining: 24.5s
# 952:	total: 22.3s	remaining: 24.5s
# 953:	total: 22.3s	remaining: 24.4s
# 954:	total: 22.3s	remaining: 24.4s
# 955:	total: 22.3s	remaining: 24.4s
# 956:	total: 22.3s	remaining: 24.4s
# 957:	total: 22.4s	remaining: 24.3s
# 958:	total: 22.4s	remaining: 24.3s
# 959:	total: 22.4s	remaining: 24.3s
# 960:	total: 22.4s	remaining: 24.2s
# 961:	total: 22.5s	remaining: 24.2s
# 962:	total: 22.5s	remaining: 24.2s
# 963:	total: 22.5s	remaining: 24.2s
# 964:	total: 22.5s	remaining: 24.1s
# 965:	total: 22.5s	remaining: 24.1s
# 966:	total: 22.6s	remaining: 24.1s
# 967:	total: 22.6s	remaining: 24.1s
# 968:	total: 22.6s	remaining: 24s
# 969:	total: 22.6s	remaining: 24s
# 970:	total: 22.6s	remaining: 24s
# 971:	total: 22.6s	remaining: 24s
# 972:	total: 22.7s	remaining: 23.9s
# 973:	total: 22.7s	remaining: 23.9s
# 974:	total: 22.7s	remaining: 23.9s
# 975:	total: 22.7s	remaining: 23.9s
# 976:	total: 22.8s	remaining: 23.8s
# 977:	total: 22.8s	remaining: 23.8s
# 978:	total: 22.8s	remaining: 23.8s
# 979:	total: 22.8s	remaining: 23.7s
# 980:	total: 22.8s	remaining: 23.7s
# 981:	total: 22.9s	remaining: 23.7s
# 982:	total: 22.9s	remaining: 23.7s
# 983:	total: 22.9s	remaining: 23.6s
# 984:	total: 22.9s	remaining: 23.6s
# 985:	total: 22.9s	remaining: 23.6s
# 986:	total: 23s	remaining: 23.6s
# 987:	total: 23s	remaining: 23.5s
# 988:	total: 23s	remaining: 23.5s
# 989:	total: 23s	remaining: 23.5s
# 990:	total: 23s	remaining: 23.5s
# 991:	total: 23.1s	remaining: 23.4s
# 992:	total: 23.1s	remaining: 23.4s
# 993:	total: 23.1s	remaining: 23.4s
# 994:	total: 23.1s	remaining: 23.4s
# 995:	total: 23.1s	remaining: 23.3s
# 996:	total: 23.2s	remaining: 23.3s
# 997:	total: 23.2s	remaining: 23.3s
# 998:	total: 23.2s	remaining: 23.2s
# 999:	total: 23.2s	remaining: 23.2s
# 1000:	total: 23.2s	remaining: 23.2s
# 1001:	total: 23.3s	remaining: 23.2s
# 1002:	total: 23.3s	remaining: 23.1s
# 1003:	total: 23.3s	remaining: 23.1s
# 1004:	total: 23.3s	remaining: 23.1s
# 1005:	total: 23.4s	remaining: 23.1s
# 1006:	total: 23.4s	remaining: 23s
# 1007:	total: 23.4s	remaining: 23s
# 1008:	total: 23.4s	remaining: 23s
# 1009:	total: 23.4s	remaining: 23s
# 1010:	total: 23.5s	remaining: 22.9s
# 1011:	total: 23.5s	remaining: 22.9s
# 1012:	total: 23.5s	remaining: 22.9s
# 1013:	total: 23.5s	remaining: 22.9s
# 1014:	total: 23.5s	remaining: 22.8s
# 1015:	total: 23.6s	remaining: 22.8s
# 1016:	total: 23.6s	remaining: 22.8s
# 1017:	total: 23.6s	remaining: 22.8s
# 1018:	total: 23.6s	remaining: 22.7s
# 1019:	total: 23.6s	remaining: 22.7s
# 1020:	total: 23.7s	remaining: 22.7s
# 1021:	total: 23.7s	remaining: 22.7s
# 1022:	total: 23.7s	remaining: 22.6s
# 1023:	total: 23.7s	remaining: 22.6s
# 1024:	total: 23.7s	remaining: 22.6s
# 1025:	total: 23.8s	remaining: 22.6s
# 1026:	total: 23.8s	remaining: 22.5s
# 1027:	total: 23.8s	remaining: 22.5s
# 1028:	total: 23.8s	remaining: 22.5s
# 1029:	total: 23.8s	remaining: 22.5s
# 1030:	total: 23.9s	remaining: 22.4s
# 1031:	total: 23.9s	remaining: 22.4s
# 1032:	total: 23.9s	remaining: 22.4s
# 1033:	total: 23.9s	remaining: 22.4s
# 1034:	total: 23.9s	remaining: 22.3s
# 1035:	total: 24s	remaining: 22.3s
# 1036:	total: 24s	remaining: 22.3s
# 1037:	total: 24s	remaining: 22.3s
# 1038:	total: 24s	remaining: 22.2s
# 1039:	total: 24.1s	remaining: 22.2s
# 1040:	total: 24.1s	remaining: 22.2s
# 1041:	total: 24.1s	remaining: 22.1s
# 1042:	total: 24.1s	remaining: 22.1s
# 1043:	total: 24.1s	remaining: 22.1s
# 1044:	total: 24.2s	remaining: 22.1s
# 1045:	total: 24.2s	remaining: 22s
# 1046:	total: 24.2s	remaining: 22s
# 1047:	total: 24.2s	remaining: 22s
# 1048:	total: 24.2s	remaining: 22s
# 1049:	total: 24.3s	remaining: 21.9s
# 1050:	total: 24.3s	remaining: 21.9s
# 1051:	total: 24.3s	remaining: 21.9s
# 1052:	total: 24.3s	remaining: 21.9s
# 1053:	total: 24.3s	remaining: 21.8s
# 1054:	total: 24.4s	remaining: 21.8s
# 1055:	total: 24.4s	remaining: 21.8s
# 1056:	total: 24.4s	remaining: 21.8s
# 1057:	total: 24.4s	remaining: 21.7s
# 1058:	total: 24.4s	remaining: 21.7s
# 1059:	total: 24.5s	remaining: 21.7s
# 1060:	total: 24.5s	remaining: 21.7s
# 1061:	total: 24.5s	remaining: 21.6s
# 1062:	total: 24.5s	remaining: 21.6s
# 1063:	total: 24.5s	remaining: 21.6s
# 1064:	total: 24.6s	remaining: 21.6s
# 1065:	total: 24.6s	remaining: 21.5s
# 1066:	total: 24.6s	remaining: 21.5s
# 1067:	total: 24.6s	remaining: 21.5s
# 1068:	total: 24.7s	remaining: 21.5s
# 1069:	total: 24.7s	remaining: 21.4s
# 1070:	total: 24.7s	remaining: 21.4s
# 1071:	total: 24.7s	remaining: 21.4s
# 1072:	total: 24.7s	remaining: 21.4s
# 1073:	total: 24.8s	remaining: 21.3s
# 1074:	total: 24.8s	remaining: 21.3s
# 1075:	total: 24.8s	remaining: 21.3s
# 1076:	total: 24.8s	remaining: 21.3s
# 1077:	total: 24.8s	remaining: 21.2s
# 1078:	total: 24.9s	remaining: 21.2s
# 1079:	total: 24.9s	remaining: 21.2s
# 1080:	total: 24.9s	remaining: 21.2s
# 1081:	total: 24.9s	remaining: 21.1s
# 1082:	total: 24.9s	remaining: 21.1s
# 1083:	total: 25s	remaining: 21.1s
# 1084:	total: 25s	remaining: 21.1s
# 1085:	total: 25s	remaining: 21s
# 1086:	total: 25s	remaining: 21s
# 1087:	total: 25s	remaining: 21s
# 1088:	total: 25.1s	remaining: 21s
# 1089:	total: 25.1s	remaining: 20.9s
# 1090:	total: 25.1s	remaining: 20.9s
# 1091:	total: 25.1s	remaining: 20.9s
# 1092:	total: 25.1s	remaining: 20.9s
# 1093:	total: 25.2s	remaining: 20.8s
# 1094:	total: 25.2s	remaining: 20.8s
# 1095:	total: 25.2s	remaining: 20.8s
# 1096:	total: 25.2s	remaining: 20.8s
# 1097:	total: 25.2s	remaining: 20.7s
# 1098:	total: 25.3s	remaining: 20.7s
# 1099:	total: 25.3s	remaining: 20.7s
# 1100:	total: 25.3s	remaining: 20.7s
# 1101:	total: 25.3s	remaining: 20.6s
# 1102:	total: 25.3s	remaining: 20.6s
# 1103:	total: 25.4s	remaining: 20.6s
# 1104:	total: 25.4s	remaining: 20.6s
# 1105:	total: 25.4s	remaining: 20.5s
# 1106:	total: 25.4s	remaining: 20.5s
# 1107:	total: 25.4s	remaining: 20.5s
# 1108:	total: 25.5s	remaining: 20.5s
# 1109:	total: 25.5s	remaining: 20.4s
# 1110:	total: 25.5s	remaining: 20.4s
# 1111:	total: 25.5s	remaining: 20.4s
# 1112:	total: 25.5s	remaining: 20.4s
# 1113:	total: 25.6s	remaining: 20.3s
# 1114:	total: 25.6s	remaining: 20.3s
# 1115:	total: 25.6s	remaining: 20.3s
# 1116:	total: 25.6s	remaining: 20.3s
# 1117:	total: 25.6s	remaining: 20.2s
# 1118:	total: 25.7s	remaining: 20.2s
# 1119:	total: 25.7s	remaining: 20.2s
# 1120:	total: 25.7s	remaining: 20.2s
# 1121:	total: 25.7s	remaining: 20.1s
# 1122:	total: 25.7s	remaining: 20.1s
# 1123:	total: 25.8s	remaining: 20.1s
# 1124:	total: 25.8s	remaining: 20.1s
# 1125:	total: 25.9s	remaining: 20.1s
# 1126:	total: 25.9s	remaining: 20s
# 1127:	total: 25.9s	remaining: 20s
# 1128:	total: 25.9s	remaining: 20s
# 1129:	total: 25.9s	remaining: 20s
# 1130:	total: 26s	remaining: 19.9s
# 1131:	total: 26s	remaining: 19.9s
# 1132:	total: 26s	remaining: 19.9s
# 1133:	total: 26s	remaining: 19.9s
# 1134:	total: 26s	remaining: 19.8s
# 1135:	total: 26.1s	remaining: 19.8s
# 1136:	total: 26.1s	remaining: 19.8s
# 1137:	total: 26.1s	remaining: 19.8s
# 1138:	total: 26.1s	remaining: 19.7s
# 1139:	total: 26.1s	remaining: 19.7s
# 1140:	total: 26.2s	remaining: 19.7s
# 1141:	total: 26.2s	remaining: 19.7s
# 1142:	total: 26.2s	remaining: 19.6s
# 1143:	total: 26.2s	remaining: 19.6s
# 1144:	total: 26.2s	remaining: 19.6s
# 1145:	total: 26.3s	remaining: 19.6s
# 1146:	total: 26.3s	remaining: 19.6s
# 1147:	total: 26.3s	remaining: 19.5s
# 1148:	total: 26.3s	remaining: 19.5s
# 1149:	total: 26.3s	remaining: 19.5s
# 1150:	total: 26.4s	remaining: 19.4s
# 1151:	total: 26.4s	remaining: 19.4s
# 1152:	total: 26.4s	remaining: 19.4s
# 1153:	total: 26.4s	remaining: 19.4s
# 1154:	total: 26.5s	remaining: 19.4s
# 1155:	total: 26.5s	remaining: 19.3s
# 1156:	total: 26.5s	remaining: 19.3s
# 1157:	total: 26.5s	remaining: 19.3s
# 1158:	total: 26.5s	remaining: 19.3s
# 1159:	total: 26.6s	remaining: 19.2s
# 1160:	total: 26.6s	remaining: 19.2s
# 1161:	total: 26.6s	remaining: 19.2s
# 1162:	total: 26.6s	remaining: 19.2s
# 1163:	total: 26.6s	remaining: 19.1s
# 1164:	total: 26.6s	remaining: 19.1s
# 1165:	total: 26.7s	remaining: 19.1s
# 1166:	total: 26.7s	remaining: 19.1s
# 1167:	total: 26.7s	remaining: 19s
# 1168:	total: 26.7s	remaining: 19s
# 1169:	total: 26.8s	remaining: 19s
# 1170:	total: 26.8s	remaining: 19s
# 1171:	total: 26.8s	remaining: 18.9s
# 1172:	total: 26.8s	remaining: 18.9s
# 1173:	total: 26.8s	remaining: 18.9s
# 1174:	total: 26.9s	remaining: 18.9s
# 1175:	total: 26.9s	remaining: 18.8s
# 1176:	total: 26.9s	remaining: 18.8s
# 1177:	total: 26.9s	remaining: 18.8s
# 1178:	total: 26.9s	remaining: 18.8s
# 1179:	total: 27s	remaining: 18.7s
# 1180:	total: 27s	remaining: 18.7s
# 1181:	total: 27s	remaining: 18.7s
# 1182:	total: 27s	remaining: 18.7s
# 1183:	total: 27s	remaining: 18.6s
# 1184:	total: 27.1s	remaining: 18.6s
# 1185:	total: 27.1s	remaining: 18.6s
# 1186:	total: 27.1s	remaining: 18.6s
# 1187:	total: 27.1s	remaining: 18.5s
# 1188:	total: 27.1s	remaining: 18.5s
# 1189:	total: 27.2s	remaining: 18.5s
# 1190:	total: 27.2s	remaining: 18.5s
# 1191:	total: 27.2s	remaining: 18.4s
# 1192:	total: 27.2s	remaining: 18.4s
# 1193:	total: 27.2s	remaining: 18.4s
# 1194:	total: 27.3s	remaining: 18.4s
# 1195:	total: 27.3s	remaining: 18.3s
# 1196:	total: 27.3s	remaining: 18.3s
# 1197:	total: 27.3s	remaining: 18.3s
# 1198:	total: 27.3s	remaining: 18.3s
# 1199:	total: 27.4s	remaining: 18.2s
# 1200:	total: 27.4s	remaining: 18.2s
# 1201:	total: 27.4s	remaining: 18.2s
# 1202:	total: 27.4s	remaining: 18.2s
# 1203:	total: 27.5s	remaining: 18.1s
# 1204:	total: 27.5s	remaining: 18.1s
# 1205:	total: 27.5s	remaining: 18.1s
# 1206:	total: 27.5s	remaining: 18.1s
# 1207:	total: 27.5s	remaining: 18.1s
# 1208:	total: 27.6s	remaining: 18s
# 1209:	total: 27.6s	remaining: 18s
# 1210:	total: 27.6s	remaining: 18s
# 1211:	total: 27.6s	remaining: 18s
# 1212:	total: 27.6s	remaining: 17.9s
# 1213:	total: 27.7s	remaining: 17.9s
# 1214:	total: 27.7s	remaining: 17.9s
# 1215:	total: 27.7s	remaining: 17.9s
# 1216:	total: 27.7s	remaining: 17.8s
# 1217:	total: 27.7s	remaining: 17.8s
# 1218:	total: 27.8s	remaining: 17.8s
# 1219:	total: 27.8s	remaining: 17.8s
# 1220:	total: 27.8s	remaining: 17.7s
# 1221:	total: 27.8s	remaining: 17.7s
# 1222:	total: 27.8s	remaining: 17.7s
# 1223:	total: 27.9s	remaining: 17.7s
# 1224:	total: 27.9s	remaining: 17.6s
# 1225:	total: 27.9s	remaining: 17.6s
# 1226:	total: 27.9s	remaining: 17.6s
# 1227:	total: 27.9s	remaining: 17.6s
# 1228:	total: 28s	remaining: 17.5s
# 1229:	total: 28s	remaining: 17.5s
# 1230:	total: 28s	remaining: 17.5s
# 1231:	total: 28s	remaining: 17.5s
# 1232:	total: 28s	remaining: 17.4s
# 1233:	total: 28.1s	remaining: 17.4s
# 1234:	total: 28.1s	remaining: 17.4s
# 1235:	total: 28.1s	remaining: 17.4s
# 1236:	total: 28.1s	remaining: 17.4s
# 1237:	total: 28.1s	remaining: 17.3s
# 1238:	total: 28.2s	remaining: 17.3s
# 1239:	total: 28.2s	remaining: 17.3s
# 1240:	total: 28.2s	remaining: 17.3s
# 1241:	total: 28.2s	remaining: 17.2s
# 1242:	total: 28.2s	remaining: 17.2s
# 1243:	total: 28.3s	remaining: 17.2s
# 1244:	total: 28.3s	remaining: 17.2s
# 1245:	total: 28.3s	remaining: 17.1s
# 1246:	total: 28.3s	remaining: 17.1s
# 1247:	total: 28.4s	remaining: 17.1s
# 1248:	total: 28.4s	remaining: 17.1s
# 1249:	total: 28.4s	remaining: 17s
# 1250:	total: 28.4s	remaining: 17s
# 1251:	total: 28.4s	remaining: 17s
# 1252:	total: 28.5s	remaining: 17s
# 1253:	total: 28.5s	remaining: 16.9s
# 1254:	total: 28.5s	remaining: 16.9s
# 1255:	total: 28.5s	remaining: 16.9s
# 1256:	total: 28.5s	remaining: 16.9s
# 1257:	total: 28.5s	remaining: 16.8s
# 1258:	total: 28.6s	remaining: 16.8s
# 1259:	total: 28.6s	remaining: 16.8s
# 1260:	total: 28.6s	remaining: 16.8s
# 1261:	total: 28.6s	remaining: 16.7s
# 1262:	total: 28.7s	remaining: 16.7s
# 1263:	total: 28.7s	remaining: 16.7s
# 1264:	total: 28.7s	remaining: 16.7s
# 1265:	total: 28.7s	remaining: 16.7s
# 1266:	total: 28.8s	remaining: 16.6s
# 1267:	total: 28.8s	remaining: 16.6s
# 1268:	total: 28.8s	remaining: 16.6s
# 1269:	total: 28.8s	remaining: 16.6s
# 1270:	total: 28.9s	remaining: 16.5s
# 1271:	total: 28.9s	remaining: 16.5s
# 1272:	total: 28.9s	remaining: 16.5s
# 1273:	total: 28.9s	remaining: 16.5s
# 1274:	total: 28.9s	remaining: 16.5s
# 1275:	total: 29s	remaining: 16.4s
# 1276:	total: 29s	remaining: 16.4s
# 1277:	total: 29s	remaining: 16.4s
# 1278:	total: 29s	remaining: 16.4s
# 1279:	total: 29s	remaining: 16.3s
# 1280:	total: 29.1s	remaining: 16.3s
# 1281:	total: 29.1s	remaining: 16.3s
# 1282:	total: 29.1s	remaining: 16.3s
# 1283:	total: 29.1s	remaining: 16.2s
# 1284:	total: 29.1s	remaining: 16.2s
# 1285:	total: 29.2s	remaining: 16.2s
# 1286:	total: 29.2s	remaining: 16.2s
# 1287:	total: 29.2s	remaining: 16.1s
# 1288:	total: 29.2s	remaining: 16.1s
# 1289:	total: 29.3s	remaining: 16.1s
# 1290:	total: 29.3s	remaining: 16.1s
# 1291:	total: 29.3s	remaining: 16.1s
# 1292:	total: 29.3s	remaining: 16s
# 1293:	total: 29.3s	remaining: 16s
# 1294:	total: 29.4s	remaining: 16s
# 1295:	total: 29.4s	remaining: 16s
# 1296:	total: 29.4s	remaining: 15.9s
# 1297:	total: 29.4s	remaining: 15.9s
# 1298:	total: 29.4s	remaining: 15.9s
# 1299:	total: 29.5s	remaining: 15.9s
# 1300:	total: 29.5s	remaining: 15.8s
# 1301:	total: 29.5s	remaining: 15.8s
# 1302:	total: 29.5s	remaining: 15.8s
# 1303:	total: 29.6s	remaining: 15.8s
# 1304:	total: 29.6s	remaining: 15.8s
# 1305:	total: 29.6s	remaining: 15.7s
# 1306:	total: 29.6s	remaining: 15.7s
# 1307:	total: 29.7s	remaining: 15.7s
# 1308:	total: 29.7s	remaining: 15.7s
# 1309:	total: 29.7s	remaining: 15.6s
# 1310:	total: 29.7s	remaining: 15.6s
# 1311:	total: 29.8s	remaining: 15.6s
# 1312:	total: 29.8s	remaining: 15.6s
# 1313:	total: 29.8s	remaining: 15.6s
# 1314:	total: 29.8s	remaining: 15.5s
# 1315:	total: 29.9s	remaining: 15.5s
# 1316:	total: 29.9s	remaining: 15.5s
# 1317:	total: 29.9s	remaining: 15.5s
# 1318:	total: 29.9s	remaining: 15.4s
# 1319:	total: 29.9s	remaining: 15.4s
# 1320:	total: 30s	remaining: 15.4s
# 1321:	total: 30s	remaining: 15.4s
# 1322:	total: 30s	remaining: 15.4s
# 1323:	total: 30.1s	remaining: 15.3s
# 1324:	total: 30.1s	remaining: 15.3s
# 1325:	total: 30.1s	remaining: 15.3s
# 1326:	total: 30.1s	remaining: 15.3s
# 1327:	total: 30.2s	remaining: 15.3s
# 1328:	total: 30.2s	remaining: 15.2s
# 1329:	total: 30.2s	remaining: 15.2s
# 1330:	total: 30.2s	remaining: 15.2s
# 1331:	total: 30.3s	remaining: 15.2s
# 1332:	total: 30.3s	remaining: 15.2s
# 1333:	total: 30.3s	remaining: 15.1s
# 1334:	total: 30.3s	remaining: 15.1s
# 1335:	total: 30.4s	remaining: 15.1s
# 1336:	total: 30.4s	remaining: 15.1s
# 1337:	total: 30.4s	remaining: 15.1s
# 1338:	total: 30.4s	remaining: 15s
# 1339:	total: 30.5s	remaining: 15s
# 1340:	total: 30.5s	remaining: 15s
# 1341:	total: 30.5s	remaining: 15s
# 1342:	total: 30.5s	remaining: 14.9s
# 1343:	total: 30.6s	remaining: 14.9s
# 1344:	total: 30.6s	remaining: 14.9s
# 1345:	total: 30.6s	remaining: 14.9s
# 1346:	total: 30.7s	remaining: 14.9s
# 1347:	total: 30.7s	remaining: 14.8s
# 1348:	total: 30.7s	remaining: 14.8s
# 1349:	total: 30.7s	remaining: 14.8s
# 1350:	total: 30.8s	remaining: 14.8s
# 1351:	total: 30.8s	remaining: 14.8s
# 1352:	total: 30.8s	remaining: 14.7s
# 1353:	total: 30.8s	remaining: 14.7s
# 1354:	total: 30.9s	remaining: 14.7s
# 1355:	total: 30.9s	remaining: 14.7s
# 1356:	total: 30.9s	remaining: 14.6s
# 1357:	total: 30.9s	remaining: 14.6s
# 1358:	total: 31s	remaining: 14.6s
# 1359:	total: 31s	remaining: 14.6s
# 1360:	total: 31s	remaining: 14.6s
# 1361:	total: 31s	remaining: 14.5s
# 1362:	total: 31.1s	remaining: 14.5s
# 1363:	total: 31.1s	remaining: 14.5s
# 1364:	total: 31.1s	remaining: 14.5s
# 1365:	total: 31.2s	remaining: 14.5s
# 1366:	total: 31.2s	remaining: 14.4s
# 1367:	total: 31.2s	remaining: 14.4s
# 1368:	total: 31.2s	remaining: 14.4s
# 1369:	total: 31.3s	remaining: 14.4s
# 1370:	total: 31.3s	remaining: 14.4s
# 1371:	total: 31.3s	remaining: 14.3s
# 1372:	total: 31.3s	remaining: 14.3s
# 1373:	total: 31.4s	remaining: 14.3s
# 1374:	total: 31.4s	remaining: 14.3s
# 1375:	total: 31.4s	remaining: 14.2s
# 1376:	total: 31.4s	remaining: 14.2s
# ...
# 1552:	total: 36.1s	remaining: 10.4s
# 1553:	total: 36.1s	remaining: 10.4s
# 1554:	total: 36.2s	remaining: 10.3s
# 1555:	total: 36.2s	remaining: 10.3s
# 1556:	total: 36.2s	remaining: 10.3s
# 1557:	total: 36.2s	remaining: 10.3s
# 1558:	total: 36.3s	remaining: 10.3s
# 1559:	total: 36.3s	remaining: 10.2s
# 1560:	total: 36.3s	remaining: 10.2s
# 1561:	total: 36.3s	remaining: 10.2s
# 1562:	total: 36.4s	remaining: 10.2s
# 1563:	total: 36.4s	remaining: 10.1s
# 1564:	total: 36.4s	remaining: 10.1s
# 1565:	total: 36.4s	remaining: 10.1s
# 1566:	total: 36.5s	remaining: 10.1s
# 1567:	total: 36.5s	remaining: 10.1s
# 1568:	total: 36.5s	remaining: 10s
# 1569:	total: 36.5s	remaining: 10s
# 1570:	total: 36.6s	remaining: 9.98s
# 1571:	total: 36.6s	remaining: 9.96s
# 1572:	total: 36.6s	remaining: 9.94s
# 1573:	total: 36.6s	remaining: 9.92s
# 1574:	total: 36.7s	remaining: 9.89s
# 1575:	total: 36.7s	remaining: 9.87s
# 1576:	total: 36.7s	remaining: 9.85s
# 1577:	total: 36.7s	remaining: 9.82s
# 1578:	total: 36.8s	remaining: 9.8s
# 1579:	total: 36.8s	remaining: 9.78s
# 1580:	total: 36.8s	remaining: 9.76s
# 1581:	total: 36.8s	remaining: 9.73s
# 1582:	total: 36.9s	remaining: 9.71s
# 1583:	total: 36.9s	remaining: 9.69s
# 1584:	total: 36.9s	remaining: 9.66s
# 1585:	total: 36.9s	remaining: 9.64s
# 1586:	total: 37s	remaining: 9.62s
# 1587:	total: 37s	remaining: 9.6s
# 1588:	total: 37s	remaining: 9.57s
# 1589:	total: 37s	remaining: 9.55s
# 1590:	total: 37.1s	remaining: 9.53s
# 1591:	total: 37.1s	remaining: 9.51s
# 1592:	total: 37.1s	remaining: 9.48s
# 1593:	total: 37.1s	remaining: 9.46s
# 1594:	total: 37.2s	remaining: 9.44s
# 1595:	total: 37.2s	remaining: 9.41s
# 1596:	total: 37.2s	remaining: 9.39s
# 1597:	total: 37.2s	remaining: 9.37s
# 1598:	total: 37.3s	remaining: 9.35s
# 1599:	total: 37.3s	remaining: 9.32s
# 1600:	total: 37.3s	remaining: 9.3s
# 1601:	total: 37.3s	remaining: 9.28s
# 1602:	total: 37.4s	remaining: 9.25s
# 1603:	total: 37.4s	remaining: 9.23s
# 1604:	total: 37.4s	remaining: 9.21s
# 1605:	total: 37.4s	remaining: 9.19s
# 1606:	total: 37.5s	remaining: 9.16s
# 1607:	total: 37.5s	remaining: 9.14s
# 1608:	total: 37.5s	remaining: 9.12s
# 1609:	total: 37.6s	remaining: 9.1s
# 1610:	total: 37.6s	remaining: 9.07s
# 1611:	total: 37.6s	remaining: 9.05s
# 1612:	total: 37.6s	remaining: 9.03s
# 1613:	total: 37.7s	remaining: 9s
# 1614:	total: 37.7s	remaining: 8.98s
# 1615:	total: 37.7s	remaining: 8.96s
# 1616:	total: 37.7s	remaining: 8.94s
# 1617:	total: 37.8s	remaining: 8.91s
# 1618:	total: 37.8s	remaining: 8.89s
# 1619:	total: 37.8s	remaining: 8.87s
# 1620:	total: 37.8s	remaining: 8.85s
# 1621:	total: 37.9s	remaining: 8.82s
# 1622:	total: 37.9s	remaining: 8.8s
# 1623:	total: 37.9s	remaining: 8.78s
# 1624:	total: 37.9s	remaining: 8.75s
# 1625:	total: 38s	remaining: 8.73s
# 1626:	total: 38s	remaining: 8.71s
# 1627:	total: 38s	remaining: 8.69s
# 1628:	total: 38.1s	remaining: 8.67s
# 1629:	total: 38.1s	remaining: 8.64s
# 1630:	total: 38.1s	remaining: 8.62s
# 1631:	total: 38.1s	remaining: 8.6s
# 1632:	total: 38.2s	remaining: 8.58s
# 1633:	total: 38.2s	remaining: 8.55s
# 1634:	total: 38.2s	remaining: 8.53s
# 1635:	total: 38.2s	remaining: 8.51s
# 1636:	total: 38.3s	remaining: 8.48s
# 1637:	total: 38.3s	remaining: 8.46s
# 1638:	total: 38.3s	remaining: 8.44s
# 1639:	total: 38.3s	remaining: 8.41s
# 1640:	total: 38.4s	remaining: 8.39s
# 1641:	total: 38.4s	remaining: 8.37s
# 1642:	total: 38.4s	remaining: 8.35s
# 1643:	total: 38.4s	remaining: 8.32s
# 1644:	total: 38.5s	remaining: 8.3s
# 1645:	total: 38.5s	remaining: 8.28s
# 1646:	total: 38.5s	remaining: 8.25s
# 1647:	total: 38.5s	remaining: 8.23s
# 1648:	total: 38.6s	remaining: 8.21s
# 1649:	total: 38.6s	remaining: 8.18s
# 1650:	total: 38.6s	remaining: 8.16s
# 1651:	total: 38.6s	remaining: 8.14s
# 1652:	total: 38.7s	remaining: 8.12s
# 1653:	total: 38.7s	remaining: 8.09s
# 1654:	total: 38.7s	remaining: 8.07s
# 1655:	total: 38.7s	remaining: 8.05s
# 1656:	total: 38.8s	remaining: 8.02s
# 1657:	total: 38.8s	remaining: 8s
# 1658:	total: 38.8s	remaining: 7.98s
# 1659:	total: 38.8s	remaining: 7.95s
# 1660:	total: 38.9s	remaining: 7.93s
# 1661:	total: 38.9s	remaining: 7.91s
# 1662:	total: 38.9s	remaining: 7.88s
# 1663:	total: 38.9s	remaining: 7.86s
# 1664:	total: 39s	remaining: 7.84s
# 1665:	total: 39s	remaining: 7.82s
# 1666:	total: 39s	remaining: 7.79s
# 1667:	total: 39s	remaining: 7.77s
# 1668:	total: 39.1s	remaining: 7.75s
# 1669:	total: 39.1s	remaining: 7.72s
# 1670:	total: 39.1s	remaining: 7.7s
# 1671:	total: 39.1s	remaining: 7.68s
# 1672:	total: 39.2s	remaining: 7.66s
# 1673:	total: 39.2s	remaining: 7.63s
# 1674:	total: 39.2s	remaining: 7.61s
# 1675:	total: 39.2s	remaining: 7.59s
# 1676:	total: 39.3s	remaining: 7.56s
# 1677:	total: 39.3s	remaining: 7.54s
# 1678:	total: 39.3s	remaining: 7.52s
# 1679:	total: 39.3s	remaining: 7.49s
# 1680:	total: 39.4s	remaining: 7.47s
# 1681:	total: 39.4s	remaining: 7.45s
# 1682:	total: 39.4s	remaining: 7.42s
# 1683:	total: 39.4s	remaining: 7.4s
# 1684:	total: 39.5s	remaining: 7.38s
# 1685:	total: 39.5s	remaining: 7.36s
# 1686:	total: 39.5s	remaining: 7.33s
# 1687:	total: 39.5s	remaining: 7.31s
# 1688:	total: 39.6s	remaining: 7.29s
# 1689:	total: 39.6s	remaining: 7.26s
# 1690:	total: 39.6s	remaining: 7.24s
# 1691:	total: 39.6s	remaining: 7.22s
# 1692:	total: 39.7s	remaining: 7.19s
# 1693:	total: 39.7s	remaining: 7.17s
# 1694:	total: 39.7s	remaining: 7.15s
# 1695:	total: 39.7s	remaining: 7.12s
# 1696:	total: 39.8s	remaining: 7.1s
# 1697:	total: 39.8s	remaining: 7.08s
# 1698:	total: 39.8s	remaining: 7.05s
# 1699:	total: 39.8s	remaining: 7.03s
# 1700:	total: 39.9s	remaining: 7.01s
# 1701:	total: 39.9s	remaining: 6.99s
# 1702:	total: 39.9s	remaining: 6.96s
# 1703:	total: 39.9s	remaining: 6.94s
# 1704:	total: 40s	remaining: 6.92s
# 1705:	total: 40s	remaining: 6.89s
# 1706:	total: 40s	remaining: 6.87s
# 1707:	total: 40s	remaining: 6.84s
# 1708:	total: 40.1s	remaining: 6.82s
# 1709:	total: 40.1s	remaining: 6.8s
# 1710:	total: 40.1s	remaining: 6.78s
# 1711:	total: 40.1s	remaining: 6.75s
# 1712:	total: 40.2s	remaining: 6.73s
# 1713:	total: 40.2s	remaining: 6.71s
# 1714:	total: 40.2s	remaining: 6.69s
# 1715:	total: 40.3s	remaining: 6.66s
# 1716:	total: 40.3s	remaining: 6.64s
# 1717:	total: 40.3s	remaining: 6.62s
# 1718:	total: 40.3s	remaining: 6.59s
# 1719:	total: 40.4s	remaining: 6.57s
# 1720:	total: 40.4s	remaining: 6.55s
# 1721:	total: 40.4s	remaining: 6.53s
# 1722:	total: 40.5s	remaining: 6.5s
# 1723:	total: 40.5s	remaining: 6.48s
# 1724:	total: 40.5s	remaining: 6.46s
# 1725:	total: 40.5s	remaining: 6.44s
# 1726:	total: 40.6s	remaining: 6.41s
# 1727:	total: 40.6s	remaining: 6.39s
# 1728:	total: 40.6s	remaining: 6.37s
# 1729:	total: 40.6s	remaining: 6.34s
# 1730:	total: 40.7s	remaining: 6.32s
# 1731:	total: 40.7s	remaining: 6.3s
# 1732:	total: 40.7s	remaining: 6.27s
# 1733:	total: 40.7s	remaining: 6.25s
# 1734:	total: 40.8s	remaining: 6.23s
# 1735:	total: 40.8s	remaining: 6.2s
# 1736:	total: 40.8s	remaining: 6.18s
# 1737:	total: 40.8s	remaining: 6.16s
# 1738:	total: 40.9s	remaining: 6.13s
# 1739:	total: 40.9s	remaining: 6.11s
# 1740:	total: 40.9s	remaining: 6.09s
# 1741:	total: 40.9s	remaining: 6.06s
# 1742:	total: 41s	remaining: 6.04s
# 1743:	total: 41s	remaining: 6.02s
# 1744:	total: 41s	remaining: 5.99s
# 1745:	total: 41s	remaining: 5.97s
# 1746:	total: 41.1s	remaining: 5.95s
# 1747:	total: 41.1s	remaining: 5.92s
# 1748:	total: 41.1s	remaining: 5.9s
# 1749:	total: 41.1s	remaining: 5.88s
# 1750:	total: 41.2s	remaining: 5.85s
# 1751:	total: 41.2s	remaining: 5.83s
# 1752:	total: 41.2s	remaining: 5.81s
# 1753:	total: 41.2s	remaining: 5.78s
# 1754:	total: 41.3s	remaining: 5.76s
# 1755:	total: 41.3s	remaining: 5.74s
# 1756:	total: 41.3s	remaining: 5.71s
# 1757:	total: 41.3s	remaining: 5.69s
# 1758:	total: 41.4s	remaining: 5.67s
# 1759:	total: 41.4s	remaining: 5.64s
# 1760:	total: 41.4s	remaining: 5.62s
# 1761:	total: 41.5s	remaining: 5.6s
# 1762:	total: 41.5s	remaining: 5.58s
# 1763:	total: 41.5s	remaining: 5.55s
# 1764:	total: 41.5s	remaining: 5.53s
# 1765:	total: 41.6s	remaining: 5.51s
# 1766:	total: 41.6s	remaining: 5.49s
# 1767:	total: 41.6s	remaining: 5.46s
# 1768:	total: 41.7s	remaining: 5.45s
# 1769:	total: 41.8s	remaining: 5.43s
# 1770:	total: 41.8s	remaining: 5.41s
# 1771:	total: 41.9s	remaining: 5.38s
# 1772:	total: 41.9s	remaining: 5.36s
# 1773:	total: 41.9s	remaining: 5.34s
# 1774:	total: 41.9s	remaining: 5.32s
# 1775:	total: 42s	remaining: 5.29s
# 1776:	total: 42s	remaining: 5.27s
# 1777:	total: 42.1s	remaining: 5.25s
# 1778:	total: 42.1s	remaining: 5.23s
# 1779:	total: 42.1s	remaining: 5.21s
# 1780:	total: 42.2s	remaining: 5.18s
# 1781:	total: 42.2s	remaining: 5.16s
# 1782:	total: 42.2s	remaining: 5.14s
# 1783:	total: 42.3s	remaining: 5.12s
# 1784:	total: 42.3s	remaining: 5.09s
# 1785:	total: 42.3s	remaining: 5.07s
# 1786:	total: 42.4s	remaining: 5.05s
# 1787:	total: 42.4s	remaining: 5.03s
# 1788:	total: 42.5s	remaining: 5.01s
# 1789:	total: 42.5s	remaining: 4.99s
# 1790:	total: 42.5s	remaining: 4.96s
# 1791:	total: 42.6s	remaining: 4.94s
# 1792:	total: 42.6s	remaining: 4.92s
# 1793:	total: 42.6s	remaining: 4.89s
# 1794:	total: 42.7s	remaining: 4.87s
# 1795:	total: 42.7s	remaining: 4.85s
# 1796:	total: 42.7s	remaining: 4.83s
# 1797:	total: 42.7s	remaining: 4.8s
# 1798:	total: 42.8s	remaining: 4.78s
# 1799:	total: 42.8s	remaining: 4.76s
# 1800:	total: 42.8s	remaining: 4.73s
# 1801:	total: 42.9s	remaining: 4.71s
# 1802:	total: 42.9s	remaining: 4.69s
# 1803:	total: 42.9s	remaining: 4.66s
# 1804:	total: 42.9s	remaining: 4.64s
# 1805:	total: 43s	remaining: 4.62s
# 1806:	total: 43s	remaining: 4.59s
# 1807:	total: 43s	remaining: 4.57s
# 1808:	total: 43.1s	remaining: 4.55s
# 1809:	total: 43.1s	remaining: 4.52s
# 1810:	total: 43.1s	remaining: 4.5s
# 1811:	total: 43.1s	remaining: 4.47s
# 1812:	total: 43.2s	remaining: 4.45s
# 1813:	total: 43.2s	remaining: 4.43s
# 1814:	total: 43.2s	remaining: 4.4s
# 1815:	total: 43.2s	remaining: 4.38s
# 1816:	total: 43.3s	remaining: 4.36s
# 1817:	total: 43.3s	remaining: 4.33s
# 1818:	total: 43.3s	remaining: 4.31s
# 1819:	total: 43.3s	remaining: 4.28s
# 1820:	total: 43.3s	remaining: 4.26s
# 1821:	total: 43.4s	remaining: 4.24s
# 1822:	total: 43.4s	remaining: 4.21s
# 1823:	total: 43.4s	remaining: 4.19s
# 1824:	total: 43.4s	remaining: 4.17s
# 1825:	total: 43.5s	remaining: 4.14s
# 1826:	total: 43.5s	remaining: 4.12s
# 1827:	total: 43.5s	remaining: 4.09s
# 1828:	total: 43.5s	remaining: 4.07s
# 1829:	total: 43.6s	remaining: 4.05s
# 1830:	total: 43.6s	remaining: 4.02s
# 1831:	total: 43.6s	remaining: 4s
# 1832:	total: 43.6s	remaining: 3.98s
# 1833:	total: 43.7s	remaining: 3.95s
# 1834:	total: 43.7s	remaining: 3.93s
# 1835:	total: 43.7s	remaining: 3.9s
# 1836:	total: 43.7s	remaining: 3.88s
# 1837:	total: 43.8s	remaining: 3.86s
# 1838:	total: 43.8s	remaining: 3.83s
# 1839:	total: 43.8s	remaining: 3.81s
# 1840:	total: 43.8s	remaining: 3.79s
# 1841:	total: 43.9s	remaining: 3.76s
# 1842:	total: 43.9s	remaining: 3.74s
# 1843:	total: 43.9s	remaining: 3.71s
# 1844:	total: 43.9s	remaining: 3.69s
# 1845:	total: 44s	remaining: 3.67s
# 1846:	total: 44s	remaining: 3.64s
# 1847:	total: 44s	remaining: 3.62s
# 1848:	total: 44s	remaining: 3.6s
# 1849:	total: 44.1s	remaining: 3.57s
# 1850:	total: 44.1s	remaining: 3.55s
# 1851:	total: 44.1s	remaining: 3.52s
# 1852:	total: 44.1s	remaining: 3.5s
# 1853:	total: 44.2s	remaining: 3.48s
# 1854:	total: 44.2s	remaining: 3.45s
# 1855:	total: 44.2s	remaining: 3.43s
# 1856:	total: 44.2s	remaining: 3.41s
# 1857:	total: 44.3s	remaining: 3.38s
# 1858:	total: 44.3s	remaining: 3.36s
# 1859:	total: 44.3s	remaining: 3.33s
# 1860:	total: 44.3s	remaining: 3.31s
# 1861:	total: 44.4s	remaining: 3.29s
# 1862:	total: 44.4s	remaining: 3.26s
# 1863:	total: 44.4s	remaining: 3.24s
# 1864:	total: 44.4s	remaining: 3.22s
# 1865:	total: 44.5s	remaining: 3.19s
# 1866:	total: 44.5s	remaining: 3.17s
# 1867:	total: 44.5s	remaining: 3.15s
# 1868:	total: 44.6s	remaining: 3.12s
# 1869:	total: 44.6s	remaining: 3.1s
# 1870:	total: 44.6s	remaining: 3.08s
# 1871:	total: 44.6s	remaining: 3.05s
# 1872:	total: 44.7s	remaining: 3.03s
# 1873:	total: 44.7s	remaining: 3s
# 1874:	total: 44.7s	remaining: 2.98s
# 1875:	total: 44.7s	remaining: 2.96s
# 1876:	total: 44.8s	remaining: 2.93s
# 1877:	total: 44.8s	remaining: 2.91s
# 1878:	total: 44.8s	remaining: 2.88s
# 1879:	total: 44.8s	remaining: 2.86s
# 1880:	total: 44.9s	remaining: 2.84s
# 1881:	total: 44.9s	remaining: 2.81s
# 1882:	total: 44.9s	remaining: 2.79s
# 1883:	total: 44.9s	remaining: 2.77s
# 1884:	total: 45s	remaining: 2.74s
# 1885:	total: 45s	remaining: 2.72s
# 1886:	total: 45s	remaining: 2.69s
# 1887:	total: 45s	remaining: 2.67s
# 1888:	total: 45.1s	remaining: 2.65s
# 1889:	total: 45.1s	remaining: 2.62s
# 1890:	total: 45.1s	remaining: 2.6s
# 1891:	total: 45.1s	remaining: 2.58s
# 1892:	total: 45.2s	remaining: 2.55s
# 1893:	total: 45.2s	remaining: 2.53s
# 1894:	total: 45.2s	remaining: 2.5s
# 1895:	total: 45.2s	remaining: 2.48s
# 1896:	total: 45.3s	remaining: 2.46s
# 1897:	total: 45.3s	remaining: 2.43s
# 1898:	total: 45.3s	remaining: 2.41s
# 1899:	total: 45.3s	remaining: 2.39s
# 1900:	total: 45.4s	remaining: 2.36s
# 1901:	total: 45.4s	remaining: 2.34s
# 1902:	total: 45.4s	remaining: 2.31s
# 1903:	total: 45.5s	remaining: 2.29s
# 1904:	total: 45.5s	remaining: 2.27s
# 1905:	total: 45.5s	remaining: 2.24s
# 1906:	total: 45.5s	remaining: 2.22s
# 1907:	total: 45.6s	remaining: 2.2s
# 1908:	total: 45.6s	remaining: 2.17s
# 1909:	total: 45.6s	remaining: 2.15s
# 1910:	total: 45.6s	remaining: 2.13s
# 1911:	total: 45.7s	remaining: 2.1s
# 1912:	total: 45.7s	remaining: 2.08s
# 1913:	total: 45.7s	remaining: 2.05s
# 1914:	total: 45.7s	remaining: 2.03s
# 1915:	total: 45.8s	remaining: 2.01s
# 1916:	total: 45.8s	remaining: 1.98s
# 1917:	total: 45.8s	remaining: 1.96s
# 1918:	total: 45.8s	remaining: 1.93s
# 1919:	total: 45.9s	remaining: 1.91s
# 1920:	total: 45.9s	remaining: 1.89s
# 1921:	total: 45.9s	remaining: 1.86s
# 1922:	total: 45.9s	remaining: 1.84s
# 1923:	total: 46s	remaining: 1.81s
# 1924:	total: 46s	remaining: 1.79s
# 1925:	total: 46s	remaining: 1.77s
# 1926:	total: 46s	remaining: 1.74s
# 1927:	total: 46.1s	remaining: 1.72s
# 1928:	total: 46.1s	remaining: 1.7s
# 1929:	total: 46.1s	remaining: 1.67s
# 1930:	total: 46.1s	remaining: 1.65s
# 1931:	total: 46.2s	remaining: 1.62s
# 1932:	total: 46.2s	remaining: 1.6s
# 1933:	total: 46.2s	remaining: 1.58s
# 1934:	total: 46.3s	remaining: 1.55s
# 1935:	total: 46.3s	remaining: 1.53s
# 1936:	total: 46.3s	remaining: 1.51s
# 1937:	total: 46.3s	remaining: 1.48s
# 1938:	total: 46.4s	remaining: 1.46s
# 1939:	total: 46.4s	remaining: 1.43s
# 1940:	total: 46.4s	remaining: 1.41s
# 1941:	total: 46.4s	remaining: 1.39s
# 1942:	total: 46.5s	remaining: 1.36s
# 1943:	total: 46.5s	remaining: 1.34s
# 1944:	total: 46.5s	remaining: 1.31s
# 1945:	total: 46.5s	remaining: 1.29s
# 1946:	total: 46.6s	remaining: 1.27s
# 1947:	total: 46.6s	remaining: 1.24s
# 1948:	total: 46.6s	remaining: 1.22s
# 1949:	total: 46.6s	remaining: 1.2s
# 1950:	total: 46.7s	remaining: 1.17s
# 1951:	total: 46.7s	remaining: 1.15s
# 1952:	total: 46.7s	remaining: 1.12s
# 1953:	total: 46.7s	remaining: 1.1s
# 1954:	total: 46.8s	remaining: 1.08s
# 1955:	total: 46.8s	remaining: 1.05s
# 1956:	total: 46.8s	remaining: 1.03s
# 1957:	total: 46.9s	remaining: 1s
# 1958:	total: 46.9s	remaining: 981ms
# 1959:	total: 46.9s	remaining: 957ms
# 1960:	total: 46.9s	remaining: 934ms
# 1961:	total: 47s	remaining: 910ms
# 1962:	total: 47s	remaining: 886ms
# 1963:	total: 47s	remaining: 862ms
# 1964:	total: 47s	remaining: 838ms
# 1965:	total: 47.1s	remaining: 814ms
# 1966:	total: 47.1s	remaining: 790ms
# 1967:	total: 47.1s	remaining: 766ms
# 1968:	total: 47.1s	remaining: 742ms
# 1969:	total: 47.2s	remaining: 718ms
# 1970:	total: 47.2s	remaining: 694ms
# 1971:	total: 47.2s	remaining: 671ms
# 1972:	total: 47.2s	remaining: 647ms
# 1973:	total: 47.3s	remaining: 623ms
# 1974:	total: 47.3s	remaining: 599ms
# 1975:	total: 47.3s	remaining: 575ms
# 1976:	total: 47.4s	remaining: 551ms
# 1977:	total: 47.4s	remaining: 527ms
# 1978:	total: 47.4s	remaining: 503ms
# 1979:	total: 47.4s	remaining: 479ms
# 1980:	total: 47.5s	remaining: 455ms
# 1981:	total: 47.5s	remaining: 431ms
# 1982:	total: 47.5s	remaining: 408ms
# 1983:	total: 47.6s	remaining: 384ms
# 1984:	total: 47.6s	remaining: 360ms
# 1985:	total: 47.6s	remaining: 336ms
# 1986:	total: 47.6s	remaining: 312ms
# 1987:	total: 47.7s	remaining: 288ms
# 1988:	total: 47.7s	remaining: 264ms
# 1989:	total: 47.7s	remaining: 240ms
# 1990:	total: 47.7s	remaining: 216ms
# 1991:	total: 47.8s	remaining: 192ms
# 1992:	total: 47.8s	remaining: 168ms
# 1993:	total: 47.8s	remaining: 144ms
# 1994:	total: 47.8s	remaining: 120ms
# 1995:	total: 47.9s	remaining: 95.9ms
# 1996:	total: 47.9s	remaining: 71.9ms
# 1997:	total: 47.9s	remaining: 48ms
# 1998:	total: 47.9s	remaining: 24ms
# 1999:	total: 48s	remaining: 0us

# %%
y_pred = cat.predict(X_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[21487  1230]
#  [ 2776  3599]]
# 0.8622989137907329
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.91     22717
#            1       0.75      0.56      0.64      6375
#
#     accuracy                           0.86     29092
#    macro avg       0.82      0.76      0.78     29092
# weighted avg       0.85      0.86      0.86     29092

# %%
# metrics.plot_roc_curve(cat, X_test, y_test)
# metrics.roc_auc_score(y_test, y_pred, average=None) 

from sklearn.metrics import RocCurveDisplay, roc_auc_score

# Assuming `cat` is your trained model, and `X_test` and `y_test` are your test data
RocCurveDisplay.from_estimator(cat, X_test, y_test)
metrics.roc_auc_score(y_test, y_pred, average=None)
# Out:
# 0.7552022731529553

# %%
rf=RandomForestClassifier()
rf.fit(X_train_res,y_train_res)
# Out:
# RandomForestClassifier()

# %%
y_pred1 = rf.predict(X_test)
print(confusion_matrix(y_test,y_pred1))
print(accuracy_score(y_test,y_pred1))
print(classification_report(y_test,y_pred1))

# %%
metrics.plot_roc_curve(rf, X_test, y_test)
metrics.roc_auc_score(y_test, y_pred1, average=None)

# %%
logreg = LogisticRegression()
logreg.fit(X_train_res, y_train_res)

# %%
y_pred2 = logreg.predict(X_test)
print(confusion_matrix(y_test,y_pred2))
print(accuracy_score(y_test,y_pred2))
print(classification_report(y_test,y_pred2))

# %%
metrics.plot_roc_curve(logreg, X_test, y_test)
metrics.roc_auc_score(y_test, y_pred2, average=None)

# %%
gnb = GaussianNB()
gnb.fit(X_train_res, y_train_res)

# %%
y_pred3 = gnb.predict(X_test)
print(confusion_matrix(y_test,y_pred3))
print(accuracy_score(y_test,y_pred3))
print(classification_report(y_test,y_pred3))

# %%
metrics.plot_roc_curve(gnb, X_test, y_test)
metrics.roc_auc_score(y_test, y_pred3, average=None)

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train_res, y_train_res)

# %%
y_pred4 = knn.predict(X_test)
print(confusion_matrix(y_test,y_pred4))
print(accuracy_score(y_test,y_pred4))
print(classification_report(y_test,y_pred4))

# %%
metrics.plot_roc_curve(knn, X_test, y_test)
metrics.roc_auc_score(y_test, y_pred4, average=None)

# %%
xgb = XGBClassifier()
xgb.fit(X_train_res, y_train_res)

# %%
y_pred6 = xgb.predict(X_test)
print(confusion_matrix(y_test,y_pred6))
print(accuracy_score(y_test,y_pred6))
print(classification_report(y_test,y_pred6))

# %%
metrics.plot_roc_curve(xgb, X_test, y_test)
metrics.roc_auc_score(y_test, y_pred6, average=None)

# %%
svc = SVC()
svc.fit(X_train_res, y_train_res)

# %%
y_pred5 = svc.predict(X_test)
print(confusion_matrix(y_test,y_pred5))
print(accuracy_score(y_test,y_pred5))
print(classification_report(y_test,y_pred5))

# %%
metrics.plot_roc_curve(svc, X_test, y_test)
metrics.roc_auc_score(y_test, y_pred5, average=None)

# %%
# joblib.dump(rf, "rf.pkl")
joblib.dump(cat, "cat.pkl")
# joblib.dump(logreg, "logreg.pkl")
# joblib.dump(gnb, "gnb.pkl")
# joblib.dump(knn, "knn.pkl")
# joblib.dump(svc, "svc.pkl")
# joblib.dump(xgb, "xgb.pkl")
# Out:
# ['cat.pkl']
